# %% [markdown]
# # Capstone project 2: Sentiment analysis of tweets

# %% [markdown]
# **Table of Content**
# - Introduction
#
# - Section A: Preparing the Test set
#     - Step A.1: Getting the authentication credentials
#     - Step A.2: Authenticating our python script
#     - Step A.3: Creating the function to build the Test set
#
# - Section B: Preparing the Training set
#
# - Section C: Pre-processing Tweets in the Data Sets (both Test and Training)
#
# - Section D: Naive Bayes Classifier
#     - Step D.1: Build a vocabulary/list of words in our training data set
#     - Step D.2: Match tweet content against our vocabulary
#     - Step D.3: Build our word feature vector
#     - Step D.4: Training the classifier
#
# - Section E: Testing the model
# - Section F: Measuring the model performance
#
# - Conclusion

# %% [markdown]
# ## Introduction

# %% [markdown]
# **What is a Sentiment Analysis and why is it useful?**
#
# Sentiment Analysis represents the use of Natural Language Processing to determine the attitude, opinions and emotions of a speaker, writer or other subject within an online mention. In other words, it is the process of determining whether a piece of writing is positive or negative. A human is able to recognize and classify a text into positive or negative. However, a computer not but can learn to do so.
#
# **On which topic?**
#
# I would like to perform a sentiment analysis on Tweets about the late blockbuster release: Joker, with Joaquin Phoenix. Out in the USA beginning of October 2019 and throughout theaters in the world later on, no doubt that Joker has divided its audience. Whether people love or hate it, the reactions were numerous. I saw it myself at the movies in Switzerland as soon as it came out, and felt exactly this way: divided. The movie received a Golden Lion win at the Venice Film Festival, I had high expectations. The complex personality of the Joker was one of the reasons I wanted to see the movie. But after visioning it, I realized it had a strong impact on me, more than expected and not only positive. The critics I read afterwards were also two-folds, both positive and negative. Therefore, I thought it would be interesting to train a classification model on Tweets on the topic of Joker.
#
# **Who is interested?**
#
# Different types of people could be interested to know the proportion of positive vs negative tweets on this topic: fans of Joaquin Phoenix and of The Dark Knight Rises, owners of movies, producers, script writers, psychologists and psychiatrists.
#
# **Methodology**
#
# I will be using the Twitter API to collect a Test set based on keywords. A function will return a list of tweets that contain our keywords selected. Each tweet’s text will see itself attributed a label (‘positive’ or ‘negative’) to classify each tweet as positive or negative. The Training set will be downloaded because it has to be labelled into ‘positive’ or ‘negative’ on a big amount of tweets. The Training set is critical to the success of the model since our model will “learn” how to do create a sentiment analysis based on the Training set.

# %%
import numpy as np
import tweepy, json
import twitter
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import time
import ssl
import requests
import csv
import pickle
from nltk.tokenize import word_tokenize
from string import punctuation 
from nltk.corpus import stopwords

# %%
from requests.exceptions import Timeout, ConnectionError
from requests.packages.urllib3.exceptions import ReadTimeoutError

# %% [markdown]
# ## Section A: Preparing The Test Set

# %% [markdown]
# **Step A.1: Getting the authentication credentials**
#
# First off, we need to visit the Twitter Developer website, log into our account, and apply for the Twitter API. This takes a couple of clicks to execute, and wait a few hours for the approval from Twitter.

# %% [markdown]
# **Step A.2: Authenticating our Python script**
#
# Since we now have our Twitter Developers login credentials (i.e. API keys and Access token), we can proceed to authenticating our program. First, we need to import the Twitter library, then create an Twitter.API object with the credentials from the “safe” place we talked about, as follows:

# %%
api = twitter.Api(consumer_key='3h2dbtJm7BchEn8NhszxhqGXF',
                  consumer_secret='kLLwKYTIZg4FyNlECC3jxI34ITTTMI22KWuq3uZjpzZid2kLVR',
                  access_token_key='3395163311-L3kfrmBLjeT2wid9IUIrmhWhg9xhwoWIuGVdtdB',
                  access_token_secret='c7yzOy6ZP7fSspILaPkPFhaIp65P9g2rzcSTqG4OgSqDD')

# %%
print(api.VerifyCredentials())
# Out:
# {"created_at": "Thu Jul 30 07:50:24 +0000 2015", "default_profile": true, "favourites_count": 2, "followers_count": 6, "friends_count": 63, "id": 3395163311, "id_str": "3395163311", "name": "Zeballos Coline", "profile_background_color": "C0DEED", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_image_url": "http://pbs.twimg.com/profile_images/958331092867665920/qtDfnmPi_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/958331092867665920/qtDfnmPi_normal.jpg", "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "screen_name": "colinezeballos", "status": {"created_at": "Tue Jan 30 13:54:39 +0000 2018", "id": 958337667451772929, "id_str": "958337667451772929", "lang": "fr", "retweet_count": 550, "retweeted": true, "retweeted_status": {"created_at": "Tue Jan 30 08:51:21 +0000 2018", "favorite_count": 593, "id": 958261338303852544, "id_str": "958261338303852544", "lang": "fr", "retweet_count": 550, "retweeted": true, "source": "<a href=\"https://www.echobox.com\" rel=\"nofollow\">Echobox Social</a>", "text": "Roger Federer est le meilleur tennisman de l\u2019histoire\u2026 mais trois femmes ont fait mieux que lui\u2026 https://t.co/vQzEJEV38p", "truncated": true}, "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "text": "RT @decodeurs: Roger Federer est le meilleur tennisman de l\u2019histoire\u2026 mais trois femmes ont fait mieux que lui https://t.co/2VmlGgp1Co http\u2026"}, "statuses_count": 3}

# %% [markdown]
# The last line in the previous code snippet is only there to verify that our API instance works.

# %% [markdown]
# **Step A.3: Creating the function to build the Test set**
#
# Now we can start on making a function that downloads the Test set that we talked about. Basically, this is going to be a function that takes a search keyword (i.e. string) as an input, searches for tweets that include this keyword and returns them as twitter.Status objects that we can iterate through.
#
# The caveat here, though, is that Twitter limits the number of requests you can make through the API for security purposes. This limit is 180 requests per 15-minute window.
# This means, we can only get up to 180 tweets using our search function every 15 minutes, which should not be a problem, as our Training set is not going to be that large anyway. For the sake of simplicity, we will limit the search to 100 tweets for now, not exceeding the allowed number of requests. Our function for searching for the tweets (i.e. Test set) will be:

# %%
def buildTestSet(search_keyword):
    try: 
        tweets_fetched = api.GetSearch(search_keyword, count = 100)
        
        print("Fetched " + str(len(tweets_fetched)) + " tweets for the term " + search_keyword)
        
        return [{"text":status.text, "label":None} for status in tweets_fetched]
    except:
        print("Unfortunately, something went wrong..")
        return None

# %% [markdown]
# As expected, this function will return a list of tweets that contain our search keyword/s.
#
# Note that we coupled — into a JSON object — every tweet’s text with a label that is NULL for now. This is merely because we are going to classify each tweet as Positive or Negative later on, in order to determine whether the sentiment on the search term is positive or negative, based on the majority count. This is how Sentiment Analysis pragmatically works.
#
# Before we move on, let’s test out our function by adding the following code after the function body:

# %%
search_term = input("Enter a search keyword:")
# Out:
# Enter a search keyword:joker, movie

# %% [markdown]
# As described in the project introduction, we will be looking for Tweets talking about the movie "Joker", we will therefore search for the keywords "joker" and "movie".

# %%
testDataSet = buildTestSet(search_term)
# Out:
# Fetched 100 tweets for the term joker, movie

# %%
len(testDataSet)
# Out:
# 100

# %% [markdown]
# We have now a variable testDataSet that contains our Test set of 100 Tweets on the movie Joker.

# %%
print(testDataSet[0:4])
# Out:
# [{'text': 'Finally saw the joker.\n\nWhile the technical aspects of the movie are stunning and the acting incredible.\n\nThat migh… https://t.co/QFIi10T0oH', 'label': None}, {'text': '"Joker" became the first R-rated movie to hit $1 billion at the box-office, and there are\u200b rumors of a sequel https://t.co/k6U8yuxsNC', 'label': None}, {'text': "Would you like to see a sequel to Joaquin Phoenix's #Joker? https://t.co/InEGd1EvME", 'label': None}, {'text': 'RT @1woo17: They had done this before for other movies such as:\nBTS Bring The Soul: The Movie\nWeathering With You\nJoker\nSpiderman: Far From…', 'label': None}]

# %% [markdown]
# These are five tweets that contain our search keywords. Now everything is set. We have our Test set and we can move on to building our Training set.

# %% [markdown]
# ## Section B: Preparing The Training Set

# %% [markdown]
# In this section, we will also be using our Twitter API instance from the last section. However, we need to get some things out the way first. We will be using a downloadable Training set. The tweets of which were all labeled as positive or negative, depending on the content. This exactly what a Training set is for.
#
# A Training set is critical to the success of the model. Data is which needs to be labeled properly with no inconsistencies or incompleteness, as training will rely heavily on the accuracy of such data and the manner of acquisition.
#
# For this task, we will be using Niek Sanders’ Corpus of over 5000 hand-classified tweets, which makes it quite reliable. There’s also a catch here. Twitter does not allow storing tweets on a personal device, even though all such data is publicly available. Therefore, the corpus includes a keyword (topic of the tweet), a label and a tweet ID number for every tweet (i.e. row in our CSV corpus). You can get the file containing the corpus through this link of a personal repository: https://github.com/karanluthra/twitter-sentiment-training/blob/master/corpus.csv

# %%
# Exploring the Training Dataset from Niek Sanders
tr_set = pd.read_csv('/Users/colinechabloz/Desktop/CapstoneProject2/corpus.csv')

# %%
tr_set.head()
# Out:
#    apple  positive  126415614616154112
# 0  apple  positive  126404574230740992
# 1  apple  positive  126402758403305474
# 2  apple  positive  126397179614068736
# 3  apple  positive  126395626979196928
# 4  apple  positive  126394830791254016

# %%
len(tr_set)
# Out:
# 5512

# %%
tr_set.values
# Out:
# array([['apple', 'positive', 126404574230740992],
#        ['apple', 'positive', 126402758403305474],
#        ['apple', 'positive', 126397179614068736],
#        ...,
#        ['twitter', 'irrelevant', 126854999442587648],
#        ['twitter', 'irrelevant', 126854818101858304],
#        ['twitter', 'irrelevant', 126854423317188608]], dtype=object)

# %% [markdown]
# The Training Dataset contains exactly 5512 (topics, label and id) of Tweets. There seems to be more labels than just 'positive' and 'negative' (ex: irrelevant). Check all values for Label:

# %%
tr_set[tr_set.columns[0]].unique()
# Out:
# array(['apple', 'google', 'microsoft', 'twitter'], dtype=object)

# %% [markdown]
# **Observation:** the first column contains topics of type:
#
# - apple
# - google
# - microsoft
# - twitter

# %%
tr_set[tr_set.columns[1]].unique()
# Out:
# array(['positive', 'negative', 'neutral', 'irrelevant'], dtype=object)

# %% [markdown]
# **Observation:** the second column contains label of type:
#
# - positive
# - negative
# - neutral
# - irrelevant
#
# The original dataset "tr_set" doesn't contain the Tweets text, but we will fetch it using the API below.

# %% [markdown]
# First, we must remember the Twitter API limit we talked about. This will also apply here, as we will be using the API to get the actual tweet text through each tweet’s ID number included in the Corpus we have. This means, to download 5000 tweets, we will need to follow:
#
# max_number_of_requests = 180
# time_window = 15 minutes = 900 seconds
# Therefore, the process should follow:
# Repeat until end-of-file: {
#     180 requests -> (900/180) sec wait
# }
#
# Let’s now write the code that does exactly that. Let’s not forget to save the tweets we retrieve through the API into a new CSV file so that we don’t have to download them every time we run the code. Our function will be as follows:

# %%
def buildTrainingSet(corpusFile, tweetDataFile):
    import csv
    import time
    
    corpus = []
    
    with open(corpusFile,'r') as csvfile:
        lineReader = csv.reader(csvfile,delimiter=',', quotechar="\"")
        for row in lineReader:
            corpus.append({"tweet_id":row[2], "label":row[1], "text":row[0]})
    
    rate_limit = 180
    sleep_time = 900/180
    
    trainingDataSet = []
    
    for tweet in corpus:
        try:
            status = api.GetStatus(tweet["tweet_id"])
            tweet["text"] = status.text
            trainingDataSet.append(tweet)
            time.sleep(sleep_time) 
        except: 
            print("Error processing:",  tweet["tweet_id"])
            continue
        
        # now we write them to the empty CSV file
    with open(tweetDataFile,'wb') as csvfile:
        linewriter = csv.writer(csvfile,delimiter=',',quotechar="\"")
        for tweet in trainingDataSet:
            try:
                linewriter.writerow([tweet["tweet_id"], tweet["text"], tweet["label"], tweet["topic"]])
            except Exception as e:
                print(e)
    return trainingDataSet

# %% [markdown]
# Explanation of the big function above. Firstly, we define the function to take two inputs, both of which are file paths:
#
# - corpusFile is the string path to the Niek Sanders’ CSV corpus file we downloaded. This file, as mentioned earlier, includes the tweet’s topic, label and id.
# - tweetDataFile is the string path to the file we would like to save the full tweets in. In contrast to corpusFile, this file will include every tweet’s text as well as topic, label and id.
#
# Next, we started with an empty list corpus. We then opened the file corpusFile and appended every tweet from the file to the list corpus.
#
# The next segment of the code deals with getting the text of tweets based on the IDs. We loop through the tweets in corpus, calling the API on every tweet to get the Tweet.Status object of the particular tweet. Afterwards, we use that same object (status) to get the text associated with it and push it into the trainingDataSet then sleep (i.e. pause execution) for five minutes (900/180 seconds) in order to abide by the request limit we talked about.
#
# Now let’s take the time to leave our script download the tweets (which will take hours) following our last function. We can do this using the following snippet:

# %%
#THIS STEP TAKES A COUPLE OF HOURS
corpusFile = "/Users/colinechabloz/Desktop/CapstoneProject2/corpus.csv"
tweetDataFile = "/Users/colinechabloz/Desktop/CapstoneProject2/tweetDataFile.csv"
trainingData = buildTrainingSet(corpusFile, tweetDataFile)

# %%
file_pi = open('/Users/colinechabloz/Desktop/CapstoneProject2/training_data.pkl', 'wb') 
pickle.dump(trainingData, file_pi)

# %% [markdown]
# I have saved the Training set obtained in a pickle file .pkl, called file_pi, and am loading it in a variable called trainingData.

# %%
file_pi = open("/Users/colinechabloz/Desktop/CapstoneProject2/training_data.pkl",'rb')
trainingData = pickle.load(file_pi)

# %%
trainingData
# Out:
# [{'tweet_id': '126415614616154112',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Now all @Apple has to do is get swype on the iphone and it will be crack. Iphone that is'},
#  {'tweet_id': '126402758403305474',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': "Hilarious @youtube video - guy does a duet with @apple 's Siri. Pretty much sums up the love affair! http://t.co/8ExbnQjY"},
#  {'tweet_id': '126397179614068736',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '@RIM you made it too easy for me to switch to @Apple iPhone. See ya!'},
#  {'tweet_id': '126379685453119488',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'The 16 strangest things Siri has said so far. I am SOOO glad that @Apple gave Siri a sense of humor! http://t.co/TWAeUDBp via @HappyPlace'},
#  {'tweet_id': '126377656416612353',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Great up close & personal event @Apple tonight in Regent St store!'},
#  {'tweet_id': '126373779483004928',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'From which companies do you experience the best customer service aside from @zappos and @apple?'},
#  {'tweet_id': '126365858481188864',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Lmao I think @apple is onto something magical! I am DYING!!! haha. Siri suggested where to find whores and where to hide a body lolol'},
#  {'tweet_id': '126360935509135362',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': "RT @PhillipRowntree: Just registered as an @apple developer... Here's hoping I can actually do it... Any help, greatly appreciated!"},
#  {'tweet_id': '126360398885687296',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Wow. Great deals on refurbed #iPad (first gen) models. RT: Apple offers great deals on refurbished 1st-gen iPads http://t.co/ukWOKBGd @Apple'},
#  {'tweet_id': '126358340220616704',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': "Just registered as an @apple developer... Here's hoping I can actually do it... Any help, greatly appreciated!"},
#  {'tweet_id': '126357982685569024',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '你好 ! Currently learning Mandarin for my upcoming trip to Hong Kong. I gotta hand it to @Apple iPhones & their uber useful flashcard apps  \ue516\ue513'},
#  {'tweet_id': '126352268705538048',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Come to the dark side 📱“@gretcheneclark: Hey @apple, if you send me a free iPhone, I will publicly and ceremoniously burn my #BlackBerry.”'},
#  {'tweet_id': '126342268603998208',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Thanks to @Apple Covent Garden #GeniusBar for replacing my MacBook keyboard/cracked wristpad during my lunch break today, out of warranty.'},
#  {'tweet_id': '126325800080392193',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '@DailyDealChat @apple Thanks!!'},
#  {'tweet_id': '126324177501302784',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'iPads Replace Bound Playbooks on Some N.F.L. Teams http://t.co/2UXAWKwf @apple @nytimes'},
#  {'tweet_id': '126322063332999169',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '@apple @siri is efffing amazing!!'},
#  {'tweet_id': '126318009647235072',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'RT @TripLingo: We\'re one of a few "Featured Education Apps" on the @Apple **Website** today, sweet! http://t.co/0yWvbe1Z'},
#  {'tweet_id': '126315223060709376',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'We\'re one of a few "Featured Education Apps" on the @Apple **Website** today, sweet! http://t.co/0yWvbe1Z'},
#  {'tweet_id': '126314687116750849',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'We did an unexpected workshop for the #iPhone4S at @apple yesterday and we got an awesome amount of info #notjustaboutthephone @gamerchik16'},
#  {'tweet_id': '126311981564178432',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '---» RT @Apple No question bro. RT @AintEeenTrippin: Should I get dis iPhone or a EVO 3D?'},
#  {'tweet_id': '126301956951117826',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': "@Twitter CEO points to @Apple as 'corporate mentor' as @iOS signups triple http://t.co/GCY8iphN"},
#  {'tweet_id': '126287654093471745',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'At the bus with my iPhone ;) thxx @apple'},
#  {'tweet_id': '126284506360578049',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '@azee1v1 @apple @umber AppStore is well done, so is iTunes on the mobile devices.  I was talking about desktop app.'},
#  {'tweet_id': '126263834968211456',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'NYTimes: Coach Wants to See You. And Bring Your iPad. http://t.co/J2FTiEnG #iPad @apple set red 42 red 42 hut hut @NFL wish I had an #iPad'},
#  {'tweet_id': '126256230397259776',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '@apple @jilive @DanielPink: Apple sells 4 million iPhone 4S units in first weekend ... Steve Jobs brilliance lives on for ever! #iphone #RVA'},
#  {'tweet_id': '126195522691280896',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '@bkad5161 than apologize to @apple ;)'},
#  {'tweet_id': '126183339945234432',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '@Apple downloads of iOS 5 are proving popular with users  -- http://t.co/NSHLfiUX'},
#  {'tweet_id': '126180209501286400',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Lmfao look at the argument I had with Siri !!\n@ijustine @apple http://t.co/D4VjL7SI'},
#  {'tweet_id': '126164430546403328',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Incredible: 4 million iPhone 4Ss in 3 days. 135% better than the iPhone 4 http://t.co/1FMJxTMM @apple #iphone4s'},
#  {'tweet_id': '126140794078892033',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': "Well @apple fixed my #ios5 battery drain problem with a replacement iPhone 4 -- it's working like a champ now"},
#  {'tweet_id': '126134400466419712',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': "Currently ordering a BRAND NEW MACBOOK PRO!!! Bahhh... my MacBook is 5 years old. I'll miss it. But it's time. cc: @Apple -"},
#  {'tweet_id': '126116898051076096',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '#Siri now knows who my dad, mom, brother and girlfriend is.  Thanks @apple'},
#  {'tweet_id': '126116614495154176',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Well at least the @apple store has amazing call waiting music! #need4s'},
#  {'tweet_id': '126112836219973632',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '#sweet... #apple replaced my glass #probono. thank you @apple'},
#  {'tweet_id': '126107965991297024',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Not Bad! @Apple Sells Over 4 Million #IPhones in Debut Weekend - Bloomberg http://t.co/AVSl3ygU - #smartphone #sm RT @VinodRad'},
#  {'tweet_id': '126104732426186752',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'loving new technology from @apple iPhone 4s, mac air and iCloud are unreal #technology'},
#  {'tweet_id': '126097426493878272',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': "I'm loving this new IOS5 update :) @apple"},
#  {'tweet_id': '126095744531832832',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Another mention for Apple Store: http://t.co/fiIOApKt - RT @floridamike Once again getting great customer service from the @apple store ...'},
#  {'tweet_id': '126084907343691776',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Time to go get my iPhone 4s.  Looking forward to sticking it to the man by no longer paying for most texts.  Thanks @apple.'},
#  {'tweet_id': '126079414986485761',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'hey @apple I hate my computer i need a #mack wanna send me a free one.'},
#  {'tweet_id': '126076238375817216',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '#iCloud set up was flawless and works like a champ! To the Cloud @Apple'},
#  {'tweet_id': '126075534894571520',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': "@Wisconsin_Mommy @Apple I'd totally email the company... I always get great service at our @Apple store!"},
#  {'tweet_id': '126064519943426048',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '@apple loving the new IOS5 upgrade for the iPhone!'},
#  {'tweet_id': '126063358037340161',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Once again getting great customer service from the @apple store at millenia mall.'},
#  {'tweet_id': '126059405941809152',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Is it just me or is #iOS5 faster for the iPad? @apple'},
#  {'tweet_id': '126057030996852737',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'making the switch from @Android to @Apple #iphone #iphone4S #smartphone #stevejobs (@ Apple Store) http://t.co/kj6pJvkH'},
#  {'tweet_id': '126049183865114624',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'So THANKFUL for the incredible people @apple for going above and beyond and offering to and replacing my  water-damaged Macbook Pro!!! Wow!'},
#  {'tweet_id': '126040074595999746',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Play on ma man. Loving the camera in the #iphone4s. Well done @apple  #fb http://t.co/tmdFqRe1'},
#  {'tweet_id': '126034495991328768',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'So yeah... @apple #iOS5 #readinglists have changed my life. #nowicanspendevenmoretimeonmyphone.'},
#  {'tweet_id': '126026756623831041',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '@Apple Safari Reader owns the worldwide web'},
#  {'tweet_id': '126019393460244481',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'I love @apple service . My case has cracked 3x and I go in and they hand me a case and I walk out'},
#  {'tweet_id': '126009748020658177',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Said to have laid out the next 4 years @apple.Jobs last iPhone is 2012 not the iPhone4S. iPhone(4G/5) 2012 is magical! http://t.co/DxxklUBp'},
#  {'tweet_id': '126002597063696384',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'i used to be with @blackberry over 4-5yrs .. after all the disruptions and lost gigs thx to their service im moving to @apple #iphone'},
#  {'tweet_id': '125999676972470272',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Apple sells 4 million iPhones in 3 days @apple keep doing what you are doing, because you are doing it well! http://t.co/ZZc6bE0w'},
#  {'tweet_id': '125978568726560768',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '4 millions in a weekend, 16 #iPhone4S per second. This is madness?! no, this is @Apple !!!'},
#  {'tweet_id': '125974505385500672',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': ".@apple you got me. I'm now invested. MacBook Pro next year. Time to get on selling more of my #android gear"},
#  {'tweet_id': '125959059957485569',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'I just sent my grandma a post card using my #CardsApp thanks @Apple'},
#  {'tweet_id': '125947912306954240',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '@KostaTsetsekas @apple Putting it in the wash is kind of the equivalent to "Will it blend?" Glad to hear it\'s still alive.'},
#  {'tweet_id': '125940394566483968',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'God Bless @YouTube, @apple for  #appletv & our bad ass system. LOVING #PrincessOfChina. GB to @coldplay & @rihanna too :)'},
#  {'tweet_id': '125925618486489088',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Been off twitter for a few days as I smashed my iPhone but @apple were very nice and gave me a new one :)'},
#  {'tweet_id': '125924446430183425',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Thank you @Apple iOS 5 for email pop up on the lock screen and opening it when unlocking.'},
#  {'tweet_id': '125922999651139584',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'One word - #wow. RT @jldavid iPhone 4S First Weekend Sales Top Four Million: http://t.co/Zx5Pw0GT (via @apple)'},
#  {'tweet_id': '125902301931126785',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'RT @MN2NOVA: Love ios5 Easter eggs. Pull down from middle top to bottom and see what pulls down. Awesome little feature! #ios5 @apple'},
#  {'tweet_id': '125901202591461376',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Love ios5 Easter eggs. Pull down from middle top to bottom and see what pulls down. Awesome little feature! #ios5 @apple'},
#  {'tweet_id': '125900497327636480',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Love #ios5 Easter eggs. Pull down from middle top to bottom and see what pulls down. Awesome little feature! @apple #lovemyiphone'},
#  {'tweet_id': '125850288488841217',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Gone for a run, beautiful morning , man do I love iOS 5 @apple, #iPhone'},
#  {'tweet_id': '125840039031738368',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '@apple your simply the best.'},
#  {'tweet_id': '125794931439702016',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': "I must admit @apple has made me a very happy camper! I have text tones now! Lol! Ring tone: #MakeMeProud Drakes vers! Text tone: Nicki's"},
#  {'tweet_id': '125728717942161408',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': "Day305, I'm thankful for the great customer service received today from @Apple via phone CS, new phone on the way #365daysofgratefulness"},
#  {'tweet_id': '125722746100531200',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Loving the new iPod update @apple'},
#  {'tweet_id': '125717622728818688',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '@alexlindsay My wife upgraded her iPhone 4. I think Siri alone is worth the upgrade. Looking forward to @Apple continuing to enhance Siri.'},
#  {'tweet_id': '125713935344214016',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '@SteveJobs being honored tonite @Apple...A truly great loss to the world.He will so be missed'},
#  {'tweet_id': '125712433087123456',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Thx @instagram Thx @apple #hypo #D-76 #tri-x http://t.co/D7EeJHBT'},
#  {'tweet_id': '125708639607599104',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Loving my new #iPhone4S thanks @apple for #ios5'},
#  {'tweet_id': '125701161926930433',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '@apple the iPhone 4s is great #genius'},
#  {'tweet_id': '125681742760771584',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '@apple Siri is amazing'},
#  {'tweet_id': '125677424565424128',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Meet #Siri, your new iPhone butler. Click the link and be amazed by all it can do: http://t.co/lvfFdCEL @Apple'},
#  {'tweet_id': '125667241978114048',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'So, I am using my work PC (NEVER EVER) to get a feel for it; it has the worst speakers ever!! @apple you have spoiled me!! #imamac'},
#  {'tweet_id': '125664375364255744',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'I ♥ @Apple http://t.co/a8on3IAa'},
#  {'tweet_id': '125662399217930240',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '@apple just got the new iOS5 upgrade with iMessage...good luck surviving now @BlackBerry'},
#  {'tweet_id': '125652668080336896',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Loving #iOS5 !! #awesome @Apple'},
#  {'tweet_id': '125648027045199873',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'RT @MattyRiesz: @kathrynyee You were right, an iPhone is a must have. #addicted {WELCOME TO THE @APPLE CLUB}'},
#  {'tweet_id': '125628199269961729',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': "@Apple's Siri is witchcraft.  What's next @googleresearch. 2 yr lead lost?"},
#  {'tweet_id': '125623745284018176',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '@Apple iOS 5 is sweet! Notifications, phone search covers mail now, wifi sync, iCloud backup and integrated Twitter are all well done.'},
#  {'tweet_id': '125618466353983488',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': "RT @katebetts: Another great James Stewart story in today's NY Times about importance of architecture in @apple retail success http://t. ..."},
#  {'tweet_id': '125610372727193601',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': "Another great James Stewart story in today's NY Times about importance of architecture in @apple retail success http://t.co/Kniz452s"},
#  {'tweet_id': '125596541028282369',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Welcome to the twitter world @MarkStuver. This is due to #iOS5 and @apple thanks guys.'},
#  {'tweet_id': '125585606100267008',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Impressive service @apple genius bar metro centre. Power cable replaced free n booked in for screen replacement for free :- D'},
#  {'tweet_id': '125562428200202240',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'RT @deb_lavoy: the nice guy at the @apple store replaced my phone gratis when I showed him the hairline  crack on the screen. thanks @apple'},
#  {'tweet_id': '125561950376701952',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'the nice guy at the @apple store replaced my phone gratis when I showed him the hairline  crack on the screen. thanks @apple'},
#  {'tweet_id': '125550135911518209',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': "My iPhone 4S battery lasted longer than a day. That hasn't happened since my edge iPhone. Nice job, @apple."},
#  {'tweet_id': '125547297072357376',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'It would have taken me 15 mins to write this with my #Blackberry. Thank u @Apple 4s for converting me and showing me the grass is greener!'},
#  {'tweet_id': '125539788546781185',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'RT @herahussain: @RickySinghPT got a new backside for my eye phone! V impressed with @apple'},
#  {'tweet_id': '125537993942515712',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '@RickySinghPT got a new backside for my eye phone! V impressed with @apple'},
#  {'tweet_id': '125537578974851072',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '#iPhone 4S in Space http://t.co/jINNHVwz this is amazing #creative @apple your products inspire people to do unbelievable things'},
#  {'tweet_id': '125524107386302465',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Thank you @apple for making my iPad 2 feel like new again with your new iOS 5!'},
#  {'tweet_id': '125501576952553472',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': "Using my awsome iPad... I love it. I love my MacBook too and my iPod. It's all amazing! I love @apple"},
#  {'tweet_id': '125501281753251840',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '@apple iOS 5 upgrade done ...... Much better feature..... Few more feature required'},
#  {'tweet_id': '125495491701125120',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'New iOS 5 update is THE BEST. iloveyou @apple'},
#  {'tweet_id': '125459338524499969',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Finally got my iPhone 4S, thanks @Apple. Stupid @att. Learned my lesson.'},
#  {'tweet_id': '125455260801179648',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'I absolutely love my iPhone 4S. Thank you, Steve and @apple.'},
#  {'tweet_id': '125423290767507456',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': "@apple - you have invented a product that actually gets my brother to call my parents when he gets where he's going. Amazing. #siri #ipod4s"},
#  {'tweet_id': '125416879035658240',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'dammit, listening to siri is making me want to upgrade. well played @apple.'},
#  {'tweet_id': '125407532893224962',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': "Create new folders from within your photo album in #iOS5, finally!! Thanks @Apple, that's been a thorn in my side for a while. #newfeature"},
#  {'tweet_id': '125402412147146752',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '@Blackberry & @Facebook U R really about to make me throw this @Blackberry in the trash an get an @Apple iPhone! @Facebook upload issues!'},
#  {'tweet_id': '125393816470568961',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '#iOS5 update submitted to @apple! Thanks for all the support!'},
#  {'tweet_id': '125356807626559488',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Awesome service from the @apple store in pc. Thanks chris!'},
#  {'tweet_id': '125338216411828224',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'I am crazy about #iOS5 . The photo cropping is the best! @apple'},
#  {'tweet_id': '125333598197911552',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '.@apple thanks for fixing this... http://t.co/wTj1ogDO'},
#  {'tweet_id': '125313088160411649',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '@apple has changed life.'},
#  {'tweet_id': '125309946723188736',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': "Mad props to the @apple employee that didn't charge me to replace the back plate on my iPhone! Made my day!"},
#  {'tweet_id': '125279987254300672',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': "The #iphone4s is  amazing. Siri's voice recognition is absolutely a step above previous attempts. Bravo @apple"},
#  {'tweet_id': '125256305647693825',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': '#iOs5 is nice and as it had to be ! Thanks @Apple'},
#  {'tweet_id': '125252188065902592',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Good support fm Kevin @apple #Bellevue store 4 biz customers TY!'},
#  {'tweet_id': '125238017299451905',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': "@Apple: Siri is amazing!!! I'm in love!"},
#  {'tweet_id': '125165176772247552',
#   'label': 'positive',
#   'topic': 'apple',
#   'text': 'Love love love iOS 5!! @apple'},
#  {'tweet_id': '126418790706712576',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'RT @cjwallace03: So apparently @apple put MB cap on your SMS with the new update. 25mb storage before it tells you your inbox is full. W ...'},
#  {'tweet_id': '126417285559762944',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'RT @Jewelz2611 @mashable @apple, iphones r 2 expensive. Most went w/ htc/galaxy. No customer loyalty w/phone comp..'},
#  {'tweet_id': '126416915664084992',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@mashable @apple, iphones r 2 expensive. Most went w/ htc/galaxy. No customer loyalty w/phone comp..'},
#  {'tweet_id': '126411162622496768',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@apple why my tunes no go on my iPhone? iPhone lonely without them. silly #iOS5'},
#  {'tweet_id': '126410591949697024',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@apple needs to hurry up and release #iTunesMatch'},
#  {'tweet_id': '126409696553861121',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Why is  #Siri always down @apple'},
#  {'tweet_id': '126408864387182593',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'I just need to exchange a cord at the apple store why do I have to wait for a genius? @apple'},
#  {'tweet_id': '126408052525105153',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@apple AirDrop #fail - Immediate "declined your request." every time'},
#  {'tweet_id': '126405185630253056',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Yellowgate? Some iPhone 4S Users Complain of Yellow Tint to Screen http://t.co/uaqrxTNk @apple @iphone4s'},
#  {'tweet_id': '126405040809312256',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'The one #iphone feature still missing since @apple first showed it.. Contacts pictures on the contacts list! Simple yet 5 major updates miss'},
#  {'tweet_id': '126400637930979329',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "Asked siri is she dreams of electric sleep. Was disappointed that she didn't have a snippy answer.  Missed opportunity @apple"},
#  {'tweet_id': '126393204550537216',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'FUCK YOU @apple DIE IN A FUCKING BLAZE INFERNO.'},
#  {'tweet_id': '126392402083708928',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "Oh, @apple. Steve obviously had nothing to do with iPhoto, as it's the perfect opposite of 'insanely great'. Get it fixed, please."},
#  {'tweet_id': '126385036441296896',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'shit, shit, shit. IOS5 update ate all my apps, data and media just like @apple said it would. This is going to take some time to rebuild.'},
#  {'tweet_id': '126382959711358976',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': ". @apple & @AT&T u cannot tell me there isn't at least 1 64GB iPhone 4S in LA or Vegas!! Give me a fucking break!!!!"},
#  {'tweet_id': '126382051661328385',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Love @apple downloads. 4 hours and i-pad now wonky! #ripstevejobs #thenonsensepersists #neednewipadguide #fatfuckingchance'},
#  {'tweet_id': '126381519513194497',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Dear @apple My new Air is now a notbook since your update killed #wifi #bug #destroying #productivity'},
#  {'tweet_id': '126380588822298625',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "I am so done with @Att and @apple 's profitering and lack of customer service, so fucking down with both!!!"},
#  {'tweet_id': '126377298650861568',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "@apple thank you for ruining my 3GS with #iOS5. You've just turned my phone into an utterly useless pile of shit."},
#  {'tweet_id': '126375381249966080',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@rogerweir no but I have the option of a  replacement iPhone 4s ?\nNot sure if I want one after having 2 duff iPhones.\n@O2 @iphone4s @apple'},
#  {'tweet_id': '126372694118768640',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'So apparently @apple put MB cap on your SMS with the new update. 25mb storage before it tells you your inbox is full. What is this 2001?'},
#  {'tweet_id': '126372040696541184',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "You know @apple It's been almost a week since I paid for iTunes Match, I would really like to use it. Any ETA on a fix?"},
#  {'tweet_id': '126363154837020672',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'removing all @apple shit.'},
#  {'tweet_id': '126361483432038400',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "So @PhoenixSwinger 's iPhone 4 is giving her a hella hard time w/ the iOS5 update @apple"},
#  {'tweet_id': '126358301393956866',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "@Apple can't send me an iPhone preordered 1hr after launching but they cans send 5 or 10 to all the jackasses who want to shoot or blend 'em"},
#  {'tweet_id': '126358272084152320',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Gotta say the @Apple itouch iphone shuffle etc.. sound quality is AWFUL.. painfully crap. Its been a downgrade from @Sony sound quality wise'},
#  {'tweet_id': '126357580741226496',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "@bisquiat @Apple the upgrade just slows down my phone so much, it's stuck half the time. uch. thankfully no other damage. sucks for you :("},
#  {'tweet_id': '126357227727626240',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "@Mayati I think @Apple didn't do such a thorough job with the step x steps for upgrade and move to iCloud. Now it's cost me mightily."},
#  {'tweet_id': '126354628999778305',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "Hey @apple now I have iOS5 my iPhone doesn't include songs that are on compilation albums under the artist's name. #whaddupwitdat"},
#  {'tweet_id': '126351972948393984',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@NickTheFNicon He can send but not rcve txts so he has an apt @apple at 4pm.Then he exclaims: And I waited a whole YEAR for this phone!!LMAO'},
#  {'tweet_id': '126348169826148352',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "Total chaos at @apple store regent street. Like an Ethiopian feeding station. Can't believe this is same co. that makes all that cool shit."},
#  {'tweet_id': '126344426854416385',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@FishMama: If you made a purchase, just wait for the @apple survey! hate going b/c of the bad #custserv'},
#  {'tweet_id': '126343931117047808',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "Correction: @ Best Buy kudos to Chris @ Alamo Ranch S.A. TX-fixed issues couldn't resolve after 1/2 day w/ @ATT & @Apple. Hero of my day!"},
#  {'tweet_id': '126343679785959424',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@phxguy88 @Apple @BGR That\'s why all the ppl who stand in line for hrs to get the "newest" model are suckers...'},
#  {'tweet_id': '126343214805426176',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Would it kill @apple to put a braille type bump on their earbuds so we know which bud is R and L in the dark.'},
#  {'tweet_id': '126334597431697408',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@APPLE Wow @MOTOROLA Just crushed your dreams....'},
#  {'tweet_id': '126331327271284736',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Oh, just fuck you, @apple. Already?? ---&gt;  iPhone 5 on schedule for summer launch? http://t.co/Ofh9PTaG via @BGR'},
#  {'tweet_id': '126327808803880960',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "@apple, \nNo, I won't wait until thursday for an available appointment just so a 'genius' can tell me I'm shit out of luck. #now"},
#  {'tweet_id': '126324573384871936',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "@Apple, on the #iPad with #iOS5, why has the Messages Icon been included when it can't be used?"},
#  {'tweet_id': '126324389741473792',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@Steelo254 yea! I pre-order through @apple and they sorry too just like #AT&T'},
#  {'tweet_id': '126324077513293824',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Interesting... @apple now requires you to have a reservation ?         #apple #iphone #4S    :  http://t.co/zZK4fTii'},
#  {'tweet_id': '126321169468100609',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@apple why is my iPhone battery so crappy #fail'},
#  {'tweet_id': '126320033369563138',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'My @Apple @macbook keyboard will not type :('},
#  {'tweet_id': '126310645443461121',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "Why doesn't @apple iCloud sync Stickies? They've always been around, just nothing every progressed w/ them!! Why apple why?  @gruber"},
#  {'tweet_id': '126309616391950336',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@apple, your new "Save a Version" function in Pages is absolutely the most awful, interrupting, counter-intuitive piece of crap in the world'},
#  {'tweet_id': '126307071984545793',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'I hate my @apple computer.  Thats 3500 dollars down the drain.'},
#  {'tweet_id': '126302386644975616',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@apple my iPhone is charging very slowly!!!!!'},
#  {'tweet_id': '126299379832336384',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@Apple #iOS5 gm on ipad1 is very slow wash better on beta7/8 solve this problem, or give me the ipad2'},
#  {'tweet_id': '126297326565330944',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "@apple Wish I could pick month, day, and YEAR when setting a new calendar item on my iPhone. Why hasn't the new iOS fixed this yet?!"},
#  {'tweet_id': '126292335540699136',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@Apple iTunes is the worst program ever. For such a great phone, you make some awful software.'},
#  {'tweet_id': '126286814578348032',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'One would think the voice recognition on the @apple tech support line would work a little better.'},
#  {'tweet_id': '126283602571964416',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "@apple $319 to repair my iPad 2, Apple you've lost me and my $700 a year, Android here I come!"},
#  {'tweet_id': '126281019476291585',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@azee1v1 @apple @umber Proper consolidation, proper syncing, stop losing my PURCHASED items, checkboxes that do what you think they will do.'},
#  {'tweet_id': '126280555980529664',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@AsimRang @apple @umber the desktop app is wack though'},
#  {'tweet_id': '126279811151831042',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'I made a reservation and yet I still have to wait in line. Humpt! Oh @apple (@ Apple Store w/ 2 others) http://t.co/JZmVBdNm'},
#  {'tweet_id': '126257645282799616',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "Dear @apple. I had to turn off all those awesome featured you just enabled. Data plan can't handle it. 200 mb of data just because #"},
#  {'tweet_id': '126251052667375616',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '#DontBeMadAtMeBecause #Android is by far better than @Apple'},
#  {'tweet_id': '126247557339947008',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@apple is there a problem with iOS 5 that is preventing audio apps and audio functions from operating properly? I keep losing sound.'},
#  {'tweet_id': '126243680129523712',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@apple #apple One thing I hater about this #mouse the #buttery finish so fast am not #happy now #macworld @macworld http://t.co/5Uh4a4Vt'},
#  {'tweet_id': '126240605419487232',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Hey @Apple: stop sending your automatically-depreciate-all-iPhones-older-than-the-4s signal. My #iPhone4 is dying rapidly processor-wise.'},
#  {'tweet_id': '126238223537152001',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Only thing bad about the new @canon camera is that it has two compact flash cards... not one of SD. SD goes in my @apple computer. Damn you!'},
#  {'tweet_id': '126221894126022656',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "Wtf @apple 64 pages for the new terms & conditions when u update ur apps from the iTunes store. Do u really think we'll read em? Really???"},
#  {'tweet_id': '126189036644728832',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'fuck u @apple'},
#  {'tweet_id': '126188946974720000',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'oh and prolly ganna be late to work bc @apple has screwed me and my phone has my only alarm on it'},
#  {'tweet_id': '126188717902802944',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'why the fuck dose my phone decide its just ganna freeze every time i try to update it so fucking sick of @apple'},
#  {'tweet_id': '126188686453907457',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '. if u need me just text me o wait u i wont get it cuz @apple fucks me every time #fuckingpissed'},
#  {'tweet_id': '126167083334643713',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Like @apple da fuck is this shit?  http://t.co/nb4DHlSg'},
#  {'tweet_id': '126163315499081728',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "RT @CircusTK: I'm wit chu!! “@ShayDiddy: Officially boycotting @ups!!! Calling @apple to curse them out next for using them wasting my t ..."},
#  {'tweet_id': '126163250172801024',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Damn it @Apple!! Whatchu done to my phone??'},
#  {'tweet_id': '126158846375903233',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Samsung seeks iPhone 4S ban in Japan and Australia\nPatent war intensifies with injunction sought against @Apple http://t.co/QmwjTvnk'},
#  {'tweet_id': '126155291288023040',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@apple, why is it every time there is iOS software update my iPad goes dead and I need to totally restore? #fail'},
#  {'tweet_id': '126153311521996800',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@apple #iOS.5 has been nothing but a pain in the ass no room for my music.. Or photos.. Or apps! Can I undo this garbage??'},
#  {'tweet_id': '126150581558591488',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@apple the reservation system not working, shows no products avail let alone iphone 4s I had the site open in 3 browsers at 9 PM and nothing'},
#  {'tweet_id': '126143926523539457',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@albertmal88 remember @apple is evil. #icloud entering the #dropbox market'},
#  {'tweet_id': '126141380409036800',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'I know a few others having same issue RT @Joelplane: 9% now on my second full charge of the day. Pissed @Apple'},
#  {'tweet_id': '126141077131497472',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '9% now on my second full charge of the day. Pissed @Apple'},
#  {'tweet_id': '126132919117938689',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'RT @ShayDiddy: @CircusTK @ups @apple both of them are bs!!! How do u tell me go between a certain time ONLY and the muh fuh is closed!'},
#  {'tweet_id': '126131535211536384',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "I'm wit chu!! “@ShayDiddy: Officially boycotting @ups!!! Calling @apple to curse them out next for using them wasting my time!”"},
#  {'tweet_id': '126129582326816769',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "iTunes is @apple's worst product. Worse than the #Newton or the hockey puck mouse. It's utterly painful to use."},
#  {'tweet_id': '126128599030956032',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Deár iCloud I HATE U , AND I HOPE YOU DIE , YOU ARE THE WORST FUCKING INVENTION IN THE WORLD , FUCK YOUUUUUUUUUUUU #iCloud @apple @stevejobs'},
#  {'tweet_id': '126127465155403777',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'i update to ios 5 and lose everything on my phone and it wont let me sign into my itunes account... thanks @Apple'},
#  {'tweet_id': '126118222746497025',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Issues with updating iTunes on my windows pc - they really are not compatible.... Sent more time talking to @Apple care than using it!!'},
#  {'tweet_id': '126106964420857857',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@apple u guys are gay'},
#  {'tweet_id': '126099775417364480',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Restored my iPhone. STILL NO TEXTS. DEAR @APPLE Y NO LOVE, Y RESTRICTIONS ON MY SMS?  Y NO TEXTS.... #iOS5 #iOS5atemydingo'},
#  {'tweet_id': '126096173198082048',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'none of my apps work after the new ios from @apple. what do i do?!?'},
#  {'tweet_id': '126094194312876032',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Seemingly endless loop of calls to @apple, @ups, @verizonwireless to investigate my missing #iphone4s. #crankywithnophone'},
#  {'tweet_id': '126089287660863488',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "@Wisconsin_Mommy @apple that's terrible!  I hope you get an apology!"},
#  {'tweet_id': '126088404084588546',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@zombiebomber have been on the phone with @verizonwireless and @apple pretty much ever since then. Really annoyed.'},
#  {'tweet_id': '126085893353250816',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@chascouponmom @apple I get they are busy w/ the new phone, but I just wanted to buy a stylus. they made me wait forever outside & never'},
#  {'tweet_id': '126084068298334208',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "@apple @iphone Please deliver my daughter's i4s, she is driving me nuts #iphone"},
#  {'tweet_id': '126079672386723840',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "Hey @apple, the SMS full message is complete shit. Yes, I'm annoyed."},
#  {'tweet_id': '126075115686465536',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Have never had such poor customer service at @Apple before! What happened? (@ Apple Store w/ 2 others) http://t.co/GKlXMUi6'},
#  {'tweet_id': '126073520504569858',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@Apple your service experience is really fucking slipping (except for cute, eyelash batting girlies). (@ Apple Store) http://t.co/dOHDEnMg'},
#  {'tweet_id': '126068917012668416',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'What was @apple thinking making #Siri totally dependent on a network connection? Siri + @ATT = utter frustration.'},
#  {'tweet_id': '126063215842037760',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Wow the Genius Bar Reservation Line @Apple is ridic right now - ___- I am not amused. #ugh'},
#  {'tweet_id': '126054048972537856',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Where is my iPhone!?!?!?!\n@apple'},
#  {'tweet_id': '126053722966069248',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@apple battery life suck on iOS 5'},
#  {'tweet_id': '126050114518261760',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'An apple update has seemed to render my work machine incapable of opening HDV video. Thanks @Apple. Zero useful productivity today.'},
#  {'tweet_id': '126044756320075776',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "@apple I committed to your cloud storage iDisk and now it's raining :-( so soon no more iDisk.  Any plans for a new service for storage?"},
#  {'tweet_id': '126044425964109824',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "Hey @apple why can't I share a reminder list from my iPhone?\nAlso why can't I login to the iCloud webpage to modify sharing from my phone?"},
#  {'tweet_id': '126037831301869568',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Apparently fuzzball crashes on #iOS5. Congratulations @apple on another incompatible upgrade'},
#  {'tweet_id': '126034507475337216',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "Can someone plz explain to me whhyy @apple is only distributing 2-3 phones per day to the sprint stores. I'm really ... http://t.co/uf9taK8f"},
#  {'tweet_id': '126031969166434304',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'GAH. @apple iOS 5 opens text messages painfully slow, on top of 3 restore attempts 2 succeed. Early adopterness gets better of me.'},
#  {'tweet_id': '126030936084189184',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Dear @apple: Why did all my PDFs and ePub files disappear from ibooks in my iPhone post ios5 upgrade? This hurts. #3GS #needsomethingtoread'},
#  {'tweet_id': '126029733325582336',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '“@CBM: Lies @apple. the battery on this new iPhone4S is definitely not any better.” &lt;&lt; check Settings: 8 times more App usage in iOS 5'},
#  {'tweet_id': '126021108641181696',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'As a huge podcast fan - I really feel like @Apple dropped the ball on this one. http://t.co/wvzPrbCI via @Carrypad'},
#  {'tweet_id': '126018120983904256',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "I don't really like Siri's voice. Perhaps @apple can get Star Wars voices just like @garmin http://t.co/pSUJg9pN"},
#  {'tweet_id': '126016585348558848',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '“@carlton858: I really hate dealing with the brain dead people at the @apple store. For such good products, customer service sucks.” in NZ?'},
#  {'tweet_id': '126014999444467712',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'I really hate dealing with the brain dead people at the @apple store. For such good products, customer service sucks.'},
#  {'tweet_id': '126012822936231936',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Anyone else seeing missing signal bars on their #iPhone 3GS with an upgrade to #iOS5? cc/ @applecanada @apple @forstall'},
#  {'tweet_id': '126008913400303616',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'RT @CBM: Lies @apple. the battery on this new iPhone4S is definitely not any better.'},
#  {'tweet_id': '126006966312108032',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Updating to IOS5 with my regular iphone4 just made it slower and messed up.. @apple give me a free 4S and we can call it even, thanks'},
#  {'tweet_id': '126006116168642560',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@apple If you want to know what customers think dont send updates with the "noreply" return address. Who invented that anyway. #useless'},
#  {'tweet_id': '126003967552524288',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Every time I try the voice control on my iPod Touch to send an iMessage, it starts playing "Who Knew" by Pink.  Still not Flawless @Apple'},
#  {'tweet_id': '126001635162992640',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Ok Hindi keyboard in #iOS5 is something to cheer about.  But @apple  what about  support for 20+ missing Indian languages!? #FAIL'},
#  {'tweet_id': '125999655011098624',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "RT @ScottDugas: Warning: if iphone apps spontaneously loose data, it might not be the app's fault - http://t.co/1SEsvWwm #ios5downgrade  ..."},
#  {'tweet_id': '125996379913986048',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@betweensundays Ah! Yeah...should be an option...hopefully @apple figures that out. Thx'},
#  {'tweet_id': '125995264325599233',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '"Waiting for items to copy" in Itunes after everything DID copy goes on, and on, and on.  Come on @Apple, what the hell?'},
#  {'tweet_id': '125994965183635456',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "@Apple unhappy again with service/product quality. Won't buy @Apple again."},
#  {'tweet_id': '125994596336533504',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Lies @apple. the battery on this new iPhone4S is definitely not any better.'},
#  {'tweet_id': '125989051101741056',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '“@philipgrey: dear @apple, why you gotta go change the way &lt;input type="number"&gt; is handled out of the blue?”'},
#  {'tweet_id': '125987979784224770',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "Been on hold with @apple customer service for 25 minutes. Wow, lt's like they're #timewarnercable."},
#  {'tweet_id': '125987439692099584',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'anyone else stuck in duped calendar/mail/battery sucking @apple hell? #iCloud and #OSX Lion are a disappointment'},
#  {'tweet_id': '125980659415138304',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "@Apple you're killing me. Excited about iOS5 no longer- tragic battery drain, genius bar wants to replace the battery. Really?"},
#  {'tweet_id': '125978454146551808',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '1st impressions  of #iOS5- Disappointed w upgrade restore. Lot of apps & folders missing @apple do  how much time went in2 orging it? #fail'},
#  {'tweet_id': '125976113657823232',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': "@PrJusto Don't question the @Apple they will remember your dissent!"},
#  {'tweet_id': '125974886006005760',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': '@apple: Multiple times siri is "having trouble connecting to the network."  Siri needs servers (and some exercise!)'},
#  {'tweet_id': '125974351035117568',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'RT @JimMcNiel: if @apple does not resolve the #Siri network issues they will need to rename a great product to Sorri - Who else is havin ...'},
#  {'tweet_id': '125973390283653120',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'dear @apple, why you gotta go change the way &lt;input type="number"&gt; is handled out of the blue?'},
#  {'tweet_id': '125969932285513728',
#   'label': 'negative',
#   'topic': 'apple',
#   'text': 'Ugh. WTF is up with all the bottlenecks @paypal @apple?'},
#  {'tweet_id': '125966385259098112',
#   'label': 'negative',
#   'topic': 'apple',
# ...
#  {'tweet_id': '126533166352699392',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'RT @p1j Android 4.0 Ice Cream Sandwich is Here with a Google Nexus in new Avtar!   http://t.co/MTu7tGx7   #android #google #nexus #BigMAMA'},
#  {'tweet_id': '126532897715929088',
#   'label': 'positive',
#   'topic': 'google',
#   'text': "Me too RT @MohamedG: Exciting day, It's Ice cream Sandwich day ;) #Google #Android"},
#  {'tweet_id': '126531552367751169',
#   'label': 'positive',
#   'topic': 'google',
#   'text': "WOW the new #Google #Nexus is just beautiful. totally gonna boost google's market share in the smart phone market."},
#  {'tweet_id': '126531180907601920',
#   'label': 'positive',
#   'topic': 'google',
#   'text': "hahaha integrated data usage manager... in sucha brilliant way, sleek design, superb and I'm only watching videos LOL #Google"},
#  {'tweet_id': '126530945976238080',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'I fancy an Ice Cream Sandwich #google #android. Wonder it will works on my HTC Desire?'},
#  {'tweet_id': '126530924576907264',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Google Ice Cream Sandwich - sounds yummy!  What do you think? http://t.co/gMsgXcq8\n#google #Android #ice cream sandwich'},
#  {'tweet_id': '126530189579649024',
#   'label': 'positive',
#   'topic': 'google',
#   'text': "Exciting day, It's Ice cream Sandwich day ;) #Google #Android"},
#  {'tweet_id': '126530027939569665',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Android 4.0 Ice Cream Sandwich is Here with a Google Nexus in new Avtar!   http://t.co/mSWX6Eo6   #android #google #nexus #BigMAMA'},
#  {'tweet_id': '126529770778411008',
#   'label': 'positive',
#   'topic': 'google',
#   'text': '@Bla1ze I was referring to #Google & #Icecreamsandwich. It looks amazing. What imo android was missing. I ... http://t.co/rE4nLZgI'},
#  {'tweet_id': '126528982807089152',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'http://t.co/QV4m1Un9 Forget the phone.. Nice UI. Liking the Scroll Feature #android #google #nexus'},
#  {'tweet_id': '126528804192653312',
#   'label': 'positive',
#   'topic': 'google',
#   'text': '#Google has finally unveiled the much awaited #Android OS Ice Cream Sandwich & it sure looks good! http://t.co/sNL38EM1'},
#  {'tweet_id': '126528264117293056',
#   'label': 'positive',
#   'topic': 'google',
#   'text': '#google Finally!! All searches for logged in users will be on https! http://t.co/RaUeRrtF'},
#  {'tweet_id': '126526219587039233',
#   'label': 'positive',
#   'topic': 'google',
#   'text': "#RIM should really take an in debt look at #Google's strategy... They released the #NDK for #Icecreamsandwich 3 HOURS after release. #ics"},
#  {'tweet_id': '126525469897146368',
#   'label': 'positive',
#   'topic': 'google',
#   'text': "RT @vattam: Man! I've fallen in love with Galaxy Nexus! #google #samsung #galaxynexus #android"},
#  {'tweet_id': '126524301259194368',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'RT @Assim99: Dear #Google, I want the Galaxy Nexus NOW. Please send it to me by email or something - I know you have the technology'},
#  {'tweet_id': '126523530903953408',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Sorry #Apple #Google and #Samsung just made you look bad. #Android is king'},
#  {'tweet_id': '126522990585315328',
#   'label': 'positive',
#   'topic': 'google',
#   'text': "#Facebook power users 'have gone to #Google+ and #Twitter' - Telegraph http://t.co/vwCiOv1f Who are they? #socialmedia"},
#  {'tweet_id': '126522810821644288',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Not impressed much with the new Android update. But good signs: a readable font, emphasis on design, and less nerdiness. #google'},
#  {'tweet_id': '126522714713370624',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Video: #Google wallet, see the wow effect http://t.co/mcW78VtG'},
#  {'tweet_id': '126522621251682304',
#   'label': 'positive',
#   'topic': 'google',
#   'text': "When I'm about to tweet something and I cant remember how to spell I go straight to #Google"},
#  {'tweet_id': '126522262768726016',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Dear #Google, I want the Galaxy Nexus NOW. Please send it to me by email or something - I know you have the technology'},
#  {'tweet_id': '126521286053724160',
#   'label': 'positive',
#   'topic': 'google',
#   'text': '#GOOGLE #ANDROID 4.0 out ;-) Available with #SAMSUNG nexus!'},
#  {'tweet_id': '126520029410885632',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Maybe not the most efficient way to browse, but fun: #Google releases an Infinite Digital Bookcase http://t.co/X1qzeX7f by @MeghanKel'},
#  {'tweet_id': '126519483752914944',
#   'label': 'positive',
#   'topic': 'google',
#   'text': "@jowyang it's difficult to pass up #google+ considering the social seo benefits of google+ vs facebook"},
#  {'tweet_id': '126519329025040384',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Ice Cream Sandwich to stop carriers bullying smartphone users #google #android http://t.co/BZNy74Nn'},
#  {'tweet_id': '126519123772588032',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'I agree with @wellis68 that the "Hangouts" on #Google+ are friggin\' awesome!”'},
#  {'tweet_id': '126518882939838464',
#   'label': 'positive',
#   'topic': 'google',
#   'text': '#google #galaxynexus #icecream great'},
#  {'tweet_id': '126516779886456832',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Google Earth Helps Locate Salmonella Hotspots http://t.co/mcz9RSDf #google'},
#  {'tweet_id': '126515760855134208',
#   'label': 'positive',
#   'topic': 'google',
#   'text': '#samsung galaxy nexus = orbital laser. #apple iphone 4s = wooden stick #google'},
#  {'tweet_id': '126513620686352384',
#   'label': 'positive',
#   'topic': 'google',
#   'text': "Ice Cream Sandwich u r really delicious Can ditch iPhone for u that's for sure. #Google launches #Android4 aka #IceCreamSandwich :)"},
#  {'tweet_id': '126513526385819648',
#   'label': 'positive',
#   'topic': 'google',
#   'text': '#google+ (: lovin it'},
#  {'tweet_id': '126513425043030016',
#   'label': 'positive',
#   'topic': 'google',
#   'text': '"Samsung and Google have closely collaborated to push the mobile experience forward. We are pleased to ... http://t.co/ecT8fYIA #Google+'},
#  {'tweet_id': '126512728297844736',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'RT @RoycinD: FINALLY ! Power + Volume = Screenshot. No more rooting required! #Google #ICS #galaxynexus'},
#  {'tweet_id': '126512631937904640',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'I want the new #google #galaxynexus. Android 4.0 is going to be the fucks'},
#  {'tweet_id': '126512208451600384',
#   'label': 'positive',
#   'topic': 'google',
#   'text': '#Google #Nexus press conference http://t.co/2WV01o5v #slick'},
#  {'tweet_id': '126511545160171520',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'S/O to #google for getting me through high school and college....you are appreciated'},
#  {'tweet_id': '126511426926944256',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'iScream u scream v all scream #android #IceCreamSandwich. A job well done by #google and a major game changer in the #mobile #OS space'},
#  {'tweet_id': '126510977335300096',
#   'label': 'positive',
#   'topic': 'google',
#   'text': '@VentureBeat I like the #google virtual bookcase thank you for sharing'},
#  {'tweet_id': '126510551789604864',
#   'label': 'positive',
#   'topic': 'google',
#   'text': "#Google's #IceCreamSandwich was revealed. I'm getting an #Android whenever I get a new phone, but I'm keeping my #iPhone for now."},
#  {'tweet_id': '126509929619132417',
#   'label': 'positive',
#   'topic': 'google',
#   'text': '#Android #Google Ice Cream Sandwich Feature Closer Look - Roboto Type Face Is "A Pleasure" To Read http://t.co/DJsp2G5B #DhilipSiva'},
#  {'tweet_id': '126509528287166464',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Fantastic work from #Samsung and #Google on the #GalaxyNexus superphone and the new #Android #ICS. Very impressive.'},
#  {'tweet_id': '126508433582211072',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'I just add my profile on the #Google+ WebGL Globe project. Add yours ! http://t.co/lpuc3xot vía @AddThis'},
#  {'tweet_id': '126507456019968000',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'i love #google'},
#  {'tweet_id': '126507105023819776',
#   'label': 'positive',
#   'topic': 'google',
#   'text': '#Google is the best invention ever!!'},
#  {'tweet_id': '126506410195431424',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'i need a hookup, stop teasing me #google http://t.co/07YR58wL i want the new #nexus'},
#  {'tweet_id': '126506064387637249',
#   'label': 'positive',
#   'topic': 'google',
#   'text': "well.....#google's #icecreamsandwich and new accompanying phone are, as usual, neat, but nothing ground-breaking"},
#  {'tweet_id': '126505384428052481',
#   'label': 'positive',
#   'topic': 'google',
#   'text': '#Android #Google Device Frame Generator Updated For Galaxy Nexus - Your Screenshots Just Got Prettier http://t.co/9bWt2W6z #DhilipSiva'},
#  {'tweet_id': '126505187752943616',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Mmm... #SmarterPhone RT @Android: Introducing Ice Cream Sandwich, the delicious new version of Android: http://t.co/AXl2K1Gs #ICS #google'},
#  {'tweet_id': '126505144878772224',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'So so excited for all of the new Android features! Awesomeness :) #Android #ICS #Google #GalaxyNexus'},
#  {'tweet_id': '126504782465732608',
#   'label': 'positive',
#   'topic': 'google',
#   'text': "#IceCreamSandwich went way and beyond what I expected. Can't wait to get it on my Nexus to play with! #Google"},
#  {'tweet_id': '126504452680187905',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Check this video out -- Introducing Galaxy Nexus. Simple, beautiful, beyond smart http://t.co/fiTI6ZIA 透過 @youtube #android #nexus #google'},
#  {'tweet_id': '126504346639802368',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Cream on the inside, clean on the outside. Ice Cream phone job. #Google'},
#  {'tweet_id': '126504013939216384',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'RT @Mr_Lister: Loves the new presentations tool for Google Docs - particularly themes and adding video via URL #google #sd33 #edchat #ed ...'},
#  {'tweet_id': '126503805369069568',
#   'label': 'positive',
#   'topic': 'google',
#   'text': "#Google's like my wife - searches things for me and completes my sentences."},
#  {'tweet_id': '126503790412181504',
#   'label': 'positive',
#   'topic': 'google',
#   'text': '#Android 4.0 Ice Cream: Introducing Galaxy Nexus. Simple, beautiful, beyond smart http://t.co/vUWgyx3N #Google'},
#  {'tweet_id': '126503029548654593',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'http://t.co/Izh7KaiU #google #nexus #prime &lt;3 #android'},
#  {'tweet_id': '126502415322193920',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Interesting bookcase..RT @VentureBeat: #Google releases an Infinite Digital Bookcase http://t.co/urxJixCe by @MeghanKel'},
#  {'tweet_id': '126502014560649216',
#   'label': 'positive',
#   'topic': 'google',
#   'text': '#google is my bff rite about now!'},
#  {'tweet_id': '126501468902658048',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Good to see #Google finally turning their focus on user experience. http://t.co/AYhOKgo8 #IceCreamSandwich #Android'},
#  {'tweet_id': '126500614552289282',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'ICS looks awesome, please let me have it on my phone!  #android #google #motorola'},
#  {'tweet_id': '126499965869625345',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Iphone 4s almost had me ... ALMOST !! Ice Cream Sandwich FTW !! http://t.co/p32Ehduq #android #google'},
#  {'tweet_id': '126499428965158912',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'There you go - according to http://t.co/4Y8aS4zz #Google+ is builtin to the OS/Nexus line? Smart move :)'},
#  {'tweet_id': '126499143282737152',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'I just add my profile on the #Google+ WebGL Globe project. Add yours ! http://t.co/UWeYalKb via @AddThis'},
#  {'tweet_id': '126498734409396224',
#   'label': 'positive',
#   'topic': 'google',
#   'text': "Thanks Android for admitting you're ugly. New font is a good start! #ics #google"},
#  {'tweet_id': '126497976314109952',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Mmmm Ice Cream Sandwich #Android #Google'},
#  {'tweet_id': '126497860752646146',
#   'label': 'positive',
#   'topic': 'google',
#   'text': "Just seen a taste of #Google's ice cream sandwich, now I want a bite"},
#  {'tweet_id': '126497655785402368',
#   'label': 'positive',
#   'topic': 'google',
#   'text': "Probably the best #IceCreamSandwich (yet)! #Samsung and #Google's event live blog by @engadget! Why haven't I switched to #Android again?"},
#  {'tweet_id': '126496739531304960',
#   'label': 'positive',
#   'topic': 'google',
#   'text': "Instant photo sharing and the people app are what's best in Ice Cream Sandwich, IMO. #google #ics"},
#  {'tweet_id': '126496342901133313',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'The new android #Nexus phone makes the #iPhone look like a cheap toy at dollar store! #tcot #android #google #RealEstate @Burkepatch'},
#  {'tweet_id': '126496262668292096',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Sweet Ice Cream Sandwich RT @Pocketlint Google Android 4.0 Ice Cream Sandwich officially detailed #google #ics http://t.co/iUY0DF5S'},
#  {'tweet_id': '126496155856142336',
#   'label': 'positive',
#   'topic': 'google',
#   'text': '"@SamsungMobileCA: Raise your hand if you now want an #Android4 #IceCreamSandwich powered #GALAXYNexus phone! #Google #Samsung"-I do!'},
#  {'tweet_id': '126496005809127424',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Siri, which #Android device should I replace my #iPhone with? #Apple vs. #Google'},
#  {'tweet_id': '126495843116265475',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'The new Google Nexus page is live! - http://t.co/zrqoeWxI #nexus #google #android #icecreamsandwich'},
#  {'tweet_id': '126495283176685569',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Are you using #Google+ and #Linkedin yet? These are essential tools to get your company and/or you on the FIRST page of Google. Contact...'},
#  {'tweet_id': '126494976396898305',
#   'label': 'positive',
#   'topic': 'google',
#   'text': "RT @SebasCoulombe: Thanks to Samsung and Google, I'm now craving for some Ice Cream Sandwich !  #IceCreamSandwich #Google #Samsung"},
#  {'tweet_id': '126494883367235585',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Introducing Galaxy Nexus. Simple, beautiful, beyond smart http://t.co/qaMj3MeR #android #ICS #google #samsung'},
#  {'tweet_id': '126494838689513473',
#   'label': 'positive',
#   'topic': 'google',
#   'text': "So glad #Google adopted a design philosophy for #Android 4.0 a.k.a It shows soooo much! This is the polish I've been waiting for!"},
#  {'tweet_id': '126494645281755136',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Thoughts on Android 4.0 #ICS? Excited to play with the new features. #android #google'},
#  {'tweet_id': '126494442290020352',
#   'label': 'positive',
#   'topic': 'google',
#   'text': 'Wow! RT @dalmaer: WebGL infinite bookcase UI http://t.co/aijYsfHO #google'},
#  {'tweet_id': '126494339248562176',
#   'label': 'positive',
#   'topic': 'google',
#   'text': "Thanks to Samsung and Google, I'm now craving for some Ice Cream Sandwich !  #IceCreamSandwich #Google #Samsung"},
#  {'tweet_id': '126494221879357440',
#   'label': 'positive',
#   'topic': 'google',
#   'text': "Google ICS looks awesome, can't wait til it gets ported over to my evo, face unlock?! ... #android #google"},
#  {'tweet_id': '126493889761787904',
#   'label': 'positive',
#   'topic': 'google',
#   'text': '@jessecablek I want it too. Now just wondering who will be carrying it in November. Or direct purchase from #google / #samsung'},
#  ...]

# %%
# Transform list into dataframe for easier manipulation
df_trainingData = pd.DataFrame(trainingData)

# %%
df_trainingData.head()
# Out:
#       label                                               text  topic  \
# 0  positive  Now all @Apple has to do is get swype on the i...  apple
# 1  positive  Hilarious @youtube video - guy does a duet wit...  apple
# 2  positive  @RIM you made it too easy for me to switch to ...  apple
# 3  positive  The 16 strangest things Siri has said so far. ...  apple
# 4  positive  Great up close & personal event @Apple tonight...  apple
#
#              tweet_id
# 0  126415614616154112
# 1  126402758403305474
# 2  126397179614068736
# 3  126379685453119488
# 4  126377656416612353

# %%
# Check that we find the same values for Label column
df_trainingData[df_trainingData.columns[0]].unique()
# Out:
# array(['positive', 'negative', 'neutral', 'irrelevant'], dtype=object)

# %%
# Check that we find the same values for Topic column
df_trainingData[df_trainingData.columns[2]].unique()
# Out:
# array(['apple', 'google', 'microsoft', 'twitter'], dtype=object)

# %% [markdown]
# **Observations:** Good! We find the topics and labels after going through the function.

# %%
df_trainingData.values
# Out:
# array([['positive',
#         'Now all @Apple has to do is get swype on the iphone and it will be crack. Iphone that is',
#         'apple', '126415614616154112'],
#        ['positive',
#         "Hilarious @youtube video - guy does a duet with @apple 's Siri. Pretty much sums up the love affair! http://t.co/8ExbnQjY",
#         'apple', '126402758403305474'],
#        ['positive',
#         '@RIM you made it too easy for me to switch to @Apple iPhone. See ya!',
#         'apple', '126397179614068736'],
#        ...,
#        ['irrelevant', 'me re copè con #twitter', 'twitter',
#         '126855687060987904'],
#        ['irrelevant',
#         '#twitter tiene la mala costumbre de ponerce bno cuano yo me voy :/',
#         'twitter', '126854999442587648'],
#        ['irrelevant',
#         'Oi @flaviasansi. Muito bem vinda ao meu #Twitter. Sempre dou followback pelo meu perfil profissional. Permaneça por aqui, certo? Abrass!',
#         'twitter', '126854818101858304']], dtype=object)

# %% [markdown]
# **Observations**: the Training Dataset now contains a column name and the Tweets' text, in addition to the topic, a label and a tweet id.

# %% [markdown]
# ## Section C: Pre-processing Tweets in The Data Sets
#
# Before we move on to the actual classification section, there is some cleaning up to do. As a matter of fact, this step is critical and usually takes a long time when building Machine Learning models. However, this will not be a problem in our task, as the data we have is relatively consistent. In other words, we know exactly what we need from it. I will express on this matter later on.
#
# **What matters and what doesn’t matter in Sentiment Analysis**
#
# Words are the most important part (to an extent that we will talk about in the upcoming section). However, when it comes to things like punctuation, you cannot get the sentiment from punctuation. Therefore, punctuation does not matter to Sentiment Analysis. Moreover, tweet components like images, videos, URLs, usernames, emojis, etc. do not contribute to the polarity (whether it is positive or negative) of the tweet. However, this is only true for this application. For instance, in another application, we could have a Deep Learning image classifier that learns and predicts whether this image that the tweet contains stands for something positive (e.g. a rainbow) or negative (e.g. a tank). When it comes to the technicality, both Sentiment Analysis and Deep Learning fall under Machine Learning. In fact, we can perform Sentiment Analysis through Deep Learning, but that’s a story for another day.
#
# **A word about the importance of normalizing/pre-processing**
#
# Normalization in the NLP context is the process of converting a list of words to a more uniform sequence. By transforming the words into a standard format, later operations can be done on the data without compromising the process. Many pre-processing steps can be taken including: lowercasing, stemming (example: troubled, troubles go into 'troubl'), lemmatization (example: troubled, troubles to into 'trouble'), stopword removal, normalizing, noise removal...
#
# So we know what we need to keep in the tweets we have and what we need to take out. This applies to both Training and Test sets. So let’s make a our pre-processor class:

# %%
class PreProcessTweets:
    def __init__(self):
        self._stopwords = set(stopwords.words('english') + list(punctuation) + ['AT_USER','URL'])
    def processTweets(self, list_of_tweets, labels ='All'):
        processedTweets=[]
        for tweet in list_of_tweets:
            if labels is not "All":
                if tweet["label"] in labels:
                    processedTweets.append((self._processTweet(tweet["text"]),tweet["label"]))
            else: 
                processedTweets.append((self._processTweet(tweet["text"]), tweet["label"])) 
        return processedTweets
    def _processTweet(self, tweet):
        tweet = tweet.lower() # convert text to lower-case
        tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', 'URL', tweet) # remove URLs
        tweet = re.sub('@[^\s]+', 'AT_USER', tweet) # remove usernames
        tweet = re.sub(r'#([^\s]+)', r'\1', tweet) # remove the # in #hashtag
        tweet = word_tokenize(tweet) # remove repeated characters (helloooooooo into hello)
        return [word for word in tweet if word not in self._stopwords]

# %% [markdown]
# **Explaining the pre-processing steps and their importance:**
#
# 1. We start off by our imported libraries. re is Python’s Regular Expressions (RegEx) library, which takes care of parsing strings and modifying them in an efficient way without having to explicitly iterate through the characters comprising the particular string. We also imported ntlk, is the Natural Processing Toolkit, which is one of the most commonly used Python libraries out there. It takes care of any processing that we need to perform on text to change its form or extract certain components from it. The class constructor removes stop words. This is a relatively big topic that you can read up on later, as it is more into Natural Language Processing and less related to our topic.
#
# 2. The processTweets function loops through all the tweets input into it, calling its neighboring function processTweet on every tweet in the list. The latter does the actual pre-processing steps:
#     - Removing stop words in english: stopr words are a set of commonly used words in a language (a, the, is, are,...). The idea behing removing these words is to remove low informtion words from the text and focus on the important words instead.
#     - Making all the text in lower-case letters. This is merely because, in almost all programming languages, “cAr” is not interpreted the same way as “car”. Therefore, it is better to normalize all characters to be lower-case across all our data.
#     - URLs and usernames are removed from the tweet. This is for the reasons we disclosed earlier.
#     - The number sign (i.e. #) is removed from every hashtag, in order to avoid hashtags being processed differently than regular words.
#     - Duplicate characters are rid off of, in order to ensure that no important word goes unprocessed even if it is spelled out in an unusual way (e.g. “caaaaar” becomes “car”).
#     - Finally, the tweet’s text is broken into words (tokenized) in order to ease its processing in the upcoming stages. This step is also called text segmentation or lexical analysis.
#
# Let’s take an example. The following tweet could be present in the data set:
#
# "@person1 retweeted @person2: Corn has got to be the most delllllicious crop in the world!!!! #corn #thoughts..."
#
# Our pre-processor will result in the tweet looking like:
#
# “AT_USER rt AT_USER corn has got to be the most delicious crop in the world corn thoughts”
#
# And finally, the tokenization will result in:
#
# {“corn”, “most”, “delicious”, “crop”, “world”, “corn”, “thoughts”}
#
# Note that our code removed duplicate characters in words as we metioned earlier (i.e. “delllllicious” became “delicious”). However, it did not remove duplicate words (i.e. “corn”) from the text, but rather kept them. This is because duplicate word play a role in determining the polarity of the text (as we will see in the upcoming section).
#
# We are all set to use our Pre-processor class. First, we will create a variable that refers to it (an object), and then call it on both the Training and Test sets as we discussed earlier:

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     /Users/colinechabloz/nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %% [markdown]
# **Note:** Remember, the Tweets' labels in the Training Dataset take 4 values: positive, negative, irrelevant and neutral. We decide at this point to select on Tweets with Label 'positive' and 'negative'.

# %%
tweetProcessor = PreProcessTweets()
preprocessedTrainingSet = tweetProcessor.processTweets(trainingData, labels=['positive', 'negative'])
preprocessedTestSet = tweetProcessor.processTweets(testDataSet)

# %% [markdown]
# **Explanation:** we apply the data wrangling/cleaning steps to both the Training Set (trainingData) and the Test set (testDataSet).

# %%
print(preprocessedTrainingSet[0:4])
# Out:
# [(['get', 'swype', 'iphone', 'crack', 'iphone'], 'positive'), (['hilarious', 'video', 'guy', 'duet', "'s", 'siri', 'pretty', 'much', 'sums', 'love', 'affair'], 'positive'), (['made', 'easy', 'switch', 'iphone', 'see', 'ya'], 'positive'), (['16', 'strangest', 'things', 'siri', 'said', 'far', 'sooo', 'glad', 'gave', 'siri', 'sense', 'humor', 'via'], 'positive')]

# %%
print(preprocessedTestSet[0:4])
# Out:
# [(['finally', 'saw', 'joker', 'technical', 'aspects', 'movie', 'stunning', 'acting', 'incredible', 'migh…'], None), (['``', 'joker', "''", 'became', 'first', 'r-rated', 'movie', 'hit', '1', 'billion', 'box-office', 'are\u200b', 'rumors', 'sequel'], None), (['would', 'like', 'see', 'sequel', 'joaquin', 'phoenix', "'s", 'joker'], None), (['rt', 'done', 'movies', 'bts', 'bring', 'soul', 'movie', 'weathering', 'joker', 'spiderman', 'far', 'from…'], None)]

# %% [markdown]
# Now we can move on to the most exciting part — classification.

# %% [markdown]
# ## Section D: Naive Bayes Classifier
#
# **What is Naive Bayes Classifier?**
#
# Naive Bayes Classifier is a classification algorithm that relies on Bayes’ Theorem. This theorem provides a way of calculating a type or probability called posterior probability, in which the probability of an event A occurring is reliant on probabilistic known background (e.g. event B evidence). For example, if Person_X only plays tennis when it is not raining outside, then, according to Bayesian statistics, the probability of Person_X playing tennis when it is not raining can be given as:
#
# P(X plays | no rain) = P(no rain | X plays)*P(x plays)/P(no rain)
#
# following Bayes’ theorem:
#
# P(A|B) = P(B|A)*P(A)/P(B)
#
# **Why Naive Bayes Classifier?**
#
# Naive Bayes (NB) are mostly used in natural language processing problems. Naive Bayes predicts the tag of a text by calculating the probability of each tag for a given text and then output the tag with the highest one. It is the most simplest one which is enough in our case.
#
# Other possible classifier:
# - Support Vector Machine:
#     - effective in high dimensional spaces;
#     - still effective in cases where number of dimensions is greater than the number of samples
#     - uses a subset of training points in the decision function (called support vectors), so it is also memory efficient (very important too!)
#
# **Conclusion:** SVM could be a good option too. Since we need to choose one, we will work with NB.
#
# All we need to know for our task is that a Naive Bayes Classifier depends on the ever-famous Bayes’ theorem. Before we move on, let’s give a quick overview of the steps we will be taking next:
#
# - Build a vocabulary (list of words) of all the words resident in our training data set.
# - Match tweet content against our vocabulary — word-by-word.
# - Build our word feature vector.
# - Plug our feature vector into the Naive Bayes Classifier.

# %% [markdown]
# **Step D.1: Building the vocabulary**
#
# A vocabulary in Natural Language Processing is a list of all speech segments available for the model. In our case, this includes all the words resident in the Training set we have, as the model can make use of all of them relatively equally — at this point, to say the least. The code will look something like this:

# %%
def buildVocabulary(preprocessedTrainingData):
    all_words = []
    
    for (words, sentiment) in preprocessedTrainingData:
        all_words.extend(words)

    wordlist = nltk.FreqDist(all_words)
    word_features = wordlist.keys()
    
    return word_features

# %% [markdown]
# This is just creating a list of all_words we have in the Training set, breaking it into word features. Those word_features are basically a list of distinct words, each of which has its frequency (number of occurrences in the set) as a key.

# %% [markdown]
# **Step D.2: Matching tweets against our vocabulary**
#
# This step is crucial, as we will go through all the words in our Training set (i.e. our word_features list), comparing every word against the tweet at hand, associating a number with the word following:
#
# "label 1 (true): if word in vocabulary is resident in tweet
# label 0 (false): if word in vocabulary is not resident in tweet"
#
# This is fairly simple to code:

# %%
def extract_features(tweet):
    tweet_words = set(tweet)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in tweet_words)
    return features

# %% [markdown]
# Given the last snippet, for every word in the word_features, we will have the JSON key ‘contains word X’, where X is the word. Every key of those will have the value True/False, according to what we said earlier about the labels — True for ‘present’ and False for ‘absent’.

# %% [markdown]
# **Step D.3: Building our feature vector**
#
# Let’s now call the last two functions we have written. This will build our final feature vector, with which we can proceed on to training.

# %%
word_features = buildVocabulary(preprocessedTrainingSet)
trainingFeatures = nltk.classify.apply_features(extract_features, preprocessedTrainingSet)

# %%
word_features
# Out:
# dict_keys(['get', 'swype', 'iphone', 'crack', 'hilarious', 'video', 'guy', 'duet', "'s", 'siri', 'pretty', 'much', 'sums', 'love', 'affair', 'made', 'easy', 'switch', 'see', 'ya', '16', 'strangest', 'things', 'said', 'far', 'sooo', 'glad', 'gave', 'sense', 'humor', 'via', 'great', 'close', 'personal', 'event', 'tonight', 'regent', 'st', 'store', 'companies', 'experience', 'best', 'customer', 'service', 'aside', 'lmao', 'think', 'onto', 'something', 'magical', 'dying', 'haha', 'suggested', 'find', 'whores', 'hide', 'body', 'lolol', 'rt', 'registered', 'developer', '...', 'hoping', 'actually', 'help', 'greatly', 'appreciated', 'wow', 'deals', 'refurbed', 'ipad', 'first', 'gen', 'models', 'apple', 'offers', 'refurbished', '1st-gen', 'ipads', '你好', 'currently', 'learning', 'mandarin', 'upcoming', 'trip', 'hong', 'kong', 'got', 'ta', 'hand', 'iphones', 'uber', 'useful', 'flashcard', 'apps', '\ue516\ue513', 'come', 'dark', 'side', '📱', '“', 'hey', 'send', 'free', 'publicly', 'ceremoniously', 'burn', 'blackberry', '”', 'thanks', 'covent', 'garden', 'geniusbar', 'replacing', 'macbook', 'keyboard/cracked', 'wristpad', 'lunch', 'break', 'today', 'warranty', 'replace', 'bound', 'playbooks', 'n.f.l', 'teams', 'efffing', 'amazing', "'re", 'one', '``', 'featured', 'education', "''", '**website**', 'sweet', 'unexpected', 'workshop', 'iphone4s', 'yesterday', 'awesome', 'amount', 'info', 'notjustaboutthephone', '--', '»', 'question', 'bro', 'dis', 'evo', '3d', 'ceo', 'points', "'corporate", 'mentor', 'signups', 'triple', 'bus', 'thxx', 'appstore', 'well', 'done', 'itunes', 'mobile', 'devices', 'talking', 'desktop', 'app', 'nytimes', 'coach', 'wants', 'bring', 'set', 'red', '42', 'hut', 'wish', 'sells', '4', 'million', '4s', 'units', 'weekend', 'steve', 'jobs', 'brilliance', 'lives', 'ever', 'rva', 'apologize', 'downloads', 'ios', '5', 'proving', 'popular', 'users', 'lmfao', 'look', 'argument', 'incredible', '4ss', '3', 'days', '135', 'better', 'fixed', 'ios5', 'battery', 'drain', 'problem', 'replacement', 'working', 'like', 'champ', 'ordering', 'brand', 'new', 'pro', 'bahhh', 'years', 'old', "'ll", 'miss', 'time', 'cc', 'knows', 'dad', 'mom', 'brother', 'girlfriend', 'least', 'call', 'waiting', 'music', 'need4s', 'replaced', 'glass', 'probono', 'thank', 'bad', 'debut', 'bloomberg', 'smartphone', 'sm', 'loving', 'technology', 'mac', 'air', 'icloud', 'unreal', "'m", 'update', 'another', 'mention', 'getting', 'go', 'looking', 'forward', 'sticking', 'man', 'longer', 'paying', 'texts', 'hate', 'computer', 'need', 'mack', 'wan', 'na', 'flawless', 'works', 'cloud', "'d", 'totally', 'email', 'company', 'always', 'upgrade', 'millenia', 'mall', 'faster', 'making', 'stevejobs', 'thankful', 'people', 'going', 'beyond', 'offering', 'water-damaged', 'play', 'camera', 'fb', 'yeah', 'readinglists', 'changed', 'life', 'nowicanspendevenmoretimeonmyphone', 'safari', 'reader', 'owns', 'worldwide', 'web', 'case', 'cracked', '3x', 'walk', 'laid', 'next', 'last', '2012', '4g/5', 'used', '4-5yrs', '..', 'disruptions', 'lost', 'gigs', 'thx', 'im', 'moving', 'keep', 'millions', 'per', 'second', 'madness', '.AT_USER', 'invested', 'year', 'selling', 'android', 'gear', 'sent', 'grandma', 'post', 'card', 'using', 'cardsapp', 'putting', 'wash', 'kind', 'equivalent', 'blend', 'hear', 'still', 'alive', 'god', 'bless', 'appletv', 'ass', 'system', 'princessofchina', 'gb', 'twitter', 'smashed', 'nice', 'pop', 'lock', 'screen', 'opening', 'unlocking', 'word', 'sales', 'top', 'four', 'easter', 'eggs', 'pull', 'middle', 'bottom', 'pulls', 'little', 'feature', 'lovemyiphone', 'gone', 'run', 'beautiful', 'morning', 'simply', 'must', 'admit', 'happy', 'camper', 'text', 'tones', 'lol', 'ring', 'tone', 'makemeproud', 'drakes', 'vers', 'nicki', 'day305', 'received', 'phone', 'cs', 'way', '365daysofgratefulness', 'ipod', 'wife', 'upgraded', '4.', 'alone', 'worth', 'continuing', 'enhance', 'honored', 'tonite', 'truly', 'loss', 'world.he', 'missed', 'hypo', 'd-76', 'tri-x', 'genius', 'meet' ...

# %%
len(word_features)
# Out:
# 2700

# %% [markdown]
# **Observations:** Our vocabulary of words contains 2700 words.

# %%
trainingFeatures
# Out:
# [({'contains(get)': True, 'contains(swype)': True, 'contains(iphone)': True, 'contains(crack)': True, 'contains(hilarious)': False, 'contains(video)': False, 'contains(guy)': False, 'contains(duet)': False, "contains('s)": False, 'contains(siri)': False, 'contains(pretty)': False, 'contains(much)': False, 'contains(sums)': False, 'contains(love)': False, 'contains(affair)': False, 'contains(made)': False, 'contains(easy)': False, 'contains(switch)': False, 'contains(see)': False, 'contains(ya)': False, 'contains(16)': False, 'contains(strangest)': False, 'contains(things)': False, 'contains(said)': False, 'contains(far)': False, 'contains(sooo)': False, 'contains(glad)': False, 'contains(gave)': False, 'contains(sense)': False, 'contains(humor)': False, 'contains(via)': False, 'contains(great)': False, 'contains(close)': False, 'contains(personal)': False, 'contains(event)': False, 'contains(tonight)': False, 'contains(regent)': False, 'contains(st)': False, 'contains(store)': False, 'contains(companies)': False, 'contains(experience)': False, 'contains(best)': False, 'contains(customer)': False, 'contains(service)': False, 'contains(aside)': False, 'contains(lmao)': False, 'contains(think)': False, 'contains(onto)': False, 'contains(something)': False, 'contains(magical)': False, 'contains(dying)': False, 'contains(haha)': False, 'contains(suggested)': False, 'contains(find)': False, 'contains(whores)': False, 'contains(hide)': False, 'contains(body)': False, 'contains(lolol)': False, 'contains(rt)': False, 'contains(registered)': False, 'contains(developer)': False, 'contains(...)': False, 'contains(hoping)': False, 'contains(actually)': False, 'contains(help)': False, 'contains(greatly)': False, 'contains(appreciated)': False, 'contains(wow)': False, 'contains(deals)': False, 'contains(refurbed)': False, 'contains(ipad)': False, 'contains(first)': False, 'contains(gen)': False, 'contains(models)': False, 'contains(apple)': False, 'contains(offers)': False, 'contains(refurbished)': False, 'contains(1st-gen)': False, 'contains(ipads)': False, 'contains(你好)': False, 'contains(currently)': False, 'contains(learning)': False, 'contains(mandarin)': False, 'contains(upcoming)': False, 'contains(trip)': False, 'contains(hong)': False, 'contains(kong)': False, 'contains(got)': False, 'contains(ta)': False, 'contains(hand)': False, 'contains(iphones)': False, 'contains(uber)': False, 'contains(useful)': False, 'contains(flashcard)': False, 'contains(apps)': False, 'contains(\ue516\ue513)': False, 'contains(come)': False, 'contains(dark)': False, 'contains(side)': False, 'contains(📱)': False, 'contains(“)': False, 'contains(hey)': False, 'contains(send)': False, 'contains(free)': False, 'contains(publicly)': False, 'contains(ceremoniously)': False, 'contains(burn)': False, 'contains(blackberry)': False, 'contains(”)': False, 'contains(thanks)': False, 'contains(covent)': False, 'contains(garden)': False, 'contains(geniusbar)': False, 'contains(replacing)': False, 'contains(macbook)': False, 'contains(keyboard/cracked)': False, 'contains(wristpad)': False, 'contains(lunch)': False, 'contains(break)': False, 'contains(today)': False, 'contains(warranty)': False, 'contains(replace)': False, 'contains(bound)': False, 'contains(playbooks)': False, 'contains(n.f.l)': False, 'contains(teams)': False, 'contains(efffing)': False, 'contains(amazing)': False, "contains('re)": False, 'contains(one)': False, 'contains(``)': False, 'contains(featured)': False, 'contains(education)': False, "contains('')": False, 'contains(**website**)': False, 'contains(sweet)': False, 'contains(unexpected)': False, 'contains(workshop)': False, 'contains(iphone4s)': False, 'contains(yesterday)': False, 'contains(awesome)': False, 'contains(amount)': False, 'contains(info)': False, 'contains(notjustaboutthephone)': False, 'contains(--)': False, 'contains(»)': False, 'contains(question)': False, 'contains(bro)': False, 'contains(dis)': False, 'contains(evo)': False,  ...

# %% [markdown]
# The NTLK built-in function apply_features does the actual feature extraction from our lists. Our final feature vector is trainingFeatures.

# %% [markdown]
# **Step D.4: Training the classifier**
#
# We have finally come to the most important — and ironically the shortest — part of our task. Thanks to NLTK, it will only take us a function call to train the model as a Naive Bayes Classifier, since the latter is built into the library:

# %%
NBayesClassifier = nltk.NaiveBayesClassifier.train(trainingFeatures)

# %% [markdown]
# We will perform a small test of our classifier by creating fake sequences of words that are particularly positive and negative to see if the classifier is efficient.

# %%
test_tweet = ['rt','hilarious', 'video', 'guy', 'duet', "'s", 'siri', 'pretty', 'much', 'sums', 'love', 'affair']
print(NBayesClassifier.classify(extract_features(test_tweet)))
# Out:
# positive

# %%
test_tweet = ['terrible','bad', 'awful', 'negative', 'duet', 'stupid', 'mean']
print(NBayesClassifier.classify(extract_features(test_tweet)))
# Out:
# negative

# %% [markdown]
# Our small and extreme tests show that the classifier is doing some job at least!

# %% [markdown]
# Now, we must run the classifier training code (i.e. nltk.NaiveBayesClassifier.train()) and test it. Note that this code could take a few minutes to execute.

# %% [markdown]
# ## Section E: Testing The Model
#
# Let's run the classifier (i.e. NBayesClassifier) on the 100 tweets that we downloaded from Twitter, according to our search terms, and get the majority vote of the labels returned by the classifier, then outputting the total positive or negative percentage (i.e. score) of the tweets.

# %%
NBResultLabels = [NBayesClassifier.classify(extract_features(tweet[0])) for tweet in preprocessedTestSet]

# get the majority vote
if NBResultLabels.count('positive') > NBResultLabels.count('negative'):
    print("Overall Positive Sentiment")
    print("Positive Sentiment Percentage = " + str(100*NBResultLabels.count('positive')/len(NBResultLabels)) + "%")
else: 
    print("Overall Negative Sentiment")
    print("Negative Sentiment Percentage = " + str(100*NBResultLabels.count('negative')/len(NBResultLabels)) + "%")
# Out:
# Overall Negative Sentiment
# Negative Sentiment Percentage = 52.0%

# %%
NBResultLabels.count('negative')
# Out:
# 52

# %% [markdown]
# **Observation:** the results of the sentiment analysis on Tweets about the movie Joker with Joaquin Phoenix that came out in October 2019 is that there is the overall sentiment is negative at 52%. These classification results coincide with the critics one can read in the newspaper and on the internet, as they are balanced between positive and negative. Let's have a look at a couple of Tweets and the assigned label to check if the classification is intuitive or not. This is a first approximate idea of our classifier's performance.

# %% [markdown]
# ## Section F: Analyzing the performance of the model

# %% [markdown]
# **Concatenate preprocessedTestSet and NBResultLabels**
#
# Making some changes on preprocessedTestSet

# %%
len(preprocessedTestSet)
# Out:
# 100

# %%
# Transform list into dataframe for easier manipulation
df_preprocessedTestSet = pd.DataFrame(preprocessedTestSet)

# %%
df_preprocessedTestSet.shape
# Out:
# (100, 2)

# %%
# Adding column names
df_preprocessedTestSet.columns = ['Tweets pre-processed', 'label']

# %%
df_preprocessedTestSet.head(10)
# Out:
#                                 Tweets pre-processed label
# 0  [finally, saw, joker, technical, aspects, movi...  None
# 1  [``, joker, '', became, first, r-rated, movie,...  None
# 2  [would, like, see, sequel, joaquin, phoenix, '...  None
# 3  [rt, done, movies, bts, bring, soul, movie, we...  None
# 4  [ashishchanchalani, ashishchanchalanimemes, ol...  None
# 5  [think, joker, new, favorite, character/movie,...  None
# 6  [rt, still, thinking, sana, harley, quinn, wan...  None
# 7                             [joker, action, movie]  None
# 8  [saw, ford, v, ferrari, last, weekend, great, ...  None
# 9                            [’, dope, joker, movie]  None

# %% [markdown]
# Making some changes on NBResultLabels

# %%
len(NBResultLabels)
# Out:
# 100

# %%
# Transform list into dataframe for easier manipulation
df_NBResultLabels = pd.DataFrame(NBResultLabels)

# %%
df_NBResultLabels.shape
# Out:
# (100, 1)

# %%
# Adding column names
df_NBResultLabels.columns = ['label']

# %%
df_NBResultLabels.head(10)
# Out:
#       label
# 0  positive
# 1  negative
# 2  negative
# 3  positive
# 4  negative
# 5  positive
# 6  negative
# 7  positive
# 8  positive
# 9  positive

# %%
# Add labels to preprocessedTestSet
test_labels = np.concatenate((df_preprocessedTestSet, df_NBResultLabels),axis=1)

# %%
test_labels
# Out:
# array([[list(['finally', 'saw', 'joker', 'technical', 'aspects', 'movie', 'stunning', 'acting', 'incredible', 'migh…']),
#         None, 'positive'],
#        [list(['``', 'joker', "''", 'became', 'first', 'r-rated', 'movie', 'hit', '1', 'billion', 'box-office', 'are\u200b', 'rumors', 'sequel']),
#         None, 'negative'],
#        [list(['would', 'like', 'see', 'sequel', 'joaquin', 'phoenix', "'s", 'joker']),
#         None, 'negative'],
#        [list(['rt', 'done', 'movies', 'bts', 'bring', 'soul', 'movie', 'weathering', 'joker', 'spiderman', 'far', 'from…']),
#         None, 'positive'],
#        [list(['ashishchanchalani', 'ashishchanchalanimemes', 'oldvideos', 'joker', 'think', 'downloaded', 'wrong', 'joker', 'movie']),
#         None, 'negative'],
#        [list(['think', 'joker', 'new', 'favorite', 'character/movie', 'love', 'every', 'actor', '’', 'played', 'get', 'new', 'parts', 'him…']),
#         None, 'positive'],
#        [list(['rt', 'still', 'thinking', 'sana', 'harley', 'quinn', 'wanted', 'chaeyoung', 'joker', 'coz', 'chaeyoung', 'love', 'movie…']),
#         None, 'negative'],
#        [list(['joker', 'action', 'movie']), None, 'positive'],
#        [list(['saw', 'ford', 'v', 'ferrari', 'last', 'weekend', 'great', 'movie', 'would', 'top', 'list', '2019', "'m", 'marvel', 'guy', 'avengers…']),
#         None, 'positive'],
#        [list(['’', 'dope', 'joker', 'movie']), None, 'positive'],
#        [list(['rt', 'joker', 'movie', '10/10']), None, 'positive'],
#        [list(['look', 'like', 'instructing', 'joker', 'dance', 'movie', '😂']),
#         None, 'positive'],
#        [list(['rt', 'would', 'like', 'see', 'sequel', 'joaquin', 'phoenix', "'s", 'joker']),
#         None, 'negative'],
#        [list(['rt', 'joker', 'staircase', 'dance', 'scene', 'absolutely', 'best', 'thing', "'ll", 'ever', 'see', 'movie', 'imagine', 'sta…']),
#         None, 'positive'],
#        [list(["'m", 'big', 'fan', 'reason', 'behind', 'saw', 'movie', 'joker', 'realized', 'great', 'god', 'gifted', 'actor']),
#         None, 'positive'],
#        [list(['joker', 'movie', 'complicated', 'sad', 'sad', '..']),
#         None, 'positive'],
#        [list(['rt', 'people', 'complain', 'dc', 'accurate', 'like', 'jared', 'leto', 'characters', 'marvel', 'tards', 'l…']),
#         None, 'positive'],
#        [list(['``', 'people', 'expect', 'behave', "don't.", '”', 'another', 'quote', 'got', 'joker', 'movie']),
#         None, 'positive'],
#        [list(['rt', 'still', 'thinking', 'sana', 'harley', 'quinn', 'wanted', 'chaeyoung', 'joker', 'coz', 'chaeyoung', 'love', 'movie…']),
#         None, 'negative'],
#        [list(['rt', 'still', 'thinking', 'sana', 'harley', 'quinn', 'wanted', 'chaeyoung', 'joker', 'coz', 'chaeyoung', 'love', 'movie…']),
#         None, 'negative'],
#        [list(['still', 'thinking', 'sana', 'harley', 'quinn', 'wanted', 'chaeyoung', 'joker', 'coz', 'chaeyoung', 'love', 'the…']),
#         None, 'negative'],
#        [list(['saturdaythoughts', 'upcoming', 'birdsofprey', 'movie', 'like', 'look', 'mo…']),
#         None, 'positive'],
#        [list(['fuckin', 'sad', 'concerning', 'na', 'nakakarelate', 'ako', 'sobra', 'dun', 'sa', 'joker', 'movie', '😔']),
#         None, 'positive'],
#        [list(['batman', 'arkham', 'asylum', 'cinematic', 'movie', 'batman', 'joker', 'dccomics', 'dc', 'superhero', 'action', 'actionmovie', 'movie…']),
#         None, 'positive'],
#        [list(['rt', 'todd', 'mcfarlane', 'says', 'joker', 'paved', 'way', 'r-rated', 'spawn', 'movie']),
#         None, 'negative'],
#        [list(['really', 'nothing', 'personal', "n't", 'hated', 'joker', 'movie', 'the…']),
#         None, 'negative'],
#        [list(['getting', 'upset', 'movie', 'like', 'knives', 'pretty', 'sus', '...', "'s", 'even…']),
#         None, 'positive'],
#        [list(['rt', 'joker', 'movie', 'joker', 'jokermovie']), None,
#         'positive'],
#        [list(['ikr', '🙄', 'follow', 'saw', 'acc', 'also', 'suspended', 'didnt', 'saw', 'after…']),
#         None, 'negative'],
#        [list(['rt', 'todd', 'mcfarlane', 'says', 'joker', 'paved', 'way', 'r-rated', 'spawn', 'movie']),
#         None, 'negative'],
#        [list(['rt', 'would', 'like', 'see', 'sequel', 'joaquin', 'phoenix', "'s", 'joker']),
#         None, 'negative'],
#        [list(['kimjiyoungborn1982', 'plot', 'gt', 'gt', 'gt', 'joker', 'movie', '2019', 'plot']),
#         None, 'negative'],
#        [list(['movie', 'character', 'played', 'robert', 'de', 'niro', 'brutally', 'murdered', '🤔🧐']),
#         None, 'negative'],
#        [list(['rt', 'jokermovie', 'passed', 'deadpool', '783m', 'deadpool2', '785m', 'counting', '50m', 'pg-13', 'upon', 'deadpool', '…']),
#         None, 'positive'],
#        [list(['rt', '“', 'one', '2019', '’', 'greatest', 'achievements.', '”', 'tickets', 'sale', 'jokermovie']),
#         None, 'positive'],
#        [list(['2', 'media', 'meaning', 'making', 'movie', 'joker', "n't", 'actually', 'want', 'start', 'movement', 'becomes…']),
#         None, 'negative'],
#        [list(['rt', 'war', '52nd', 'day', 'collection', '🔥', 'hindi', '₹', '303.61', 'cr', 'total', '₹', '318.87', 'cr', '💵', 'worldwide', '₹', '478.50', 'cr', 'top', '6th', 'movie', 'tym', '🙏🏻', 'agr…']),
#         None, 'negative'],
#        [list(['rt', '``', 'jokes', "''", 'acrylic', 'canvas', 'loved', 'joker', 'movie', 'reminds', 'society', 'wearenigeriancreatives']),
#         None, 'positive'],
#        [list(['rt', '``', 'jokes', "''", 'acrylic', 'canvas', 'loved', 'joker', 'movie', 'reminds', 'society', 'wearenigeriancreatives']),
#         None, 'positive'],
#        [list(['rt', 'would', 'like', 'see', 'sequel', 'joaquin', 'phoenix', "'s", 'joker']),
#         None, 'negative'],
#        [list(['rt', '``', 'jokes', "''", 'acrylic', 'canvas', 'loved', 'joker', 'movie', 'reminds', 'society', 'wearenigeriancreatives']),
#         None, 'positive'],
#        [list(['apparently', 'understand', 'premise', 'movie', 'character', 'evolved', 'becoming', 'joker']),
#         None, 'negative'],
#        [list(['rt', 'done', 'movies', 'bts', 'bring', 'soul', 'movie', 'weathering', 'joker', 'spiderman', 'far', 'from…']),
#         None, 'positive'],
#        [list(['finally', 'watch', 'joker', 'incredible', 'movie']), None,
#         'positive'],
#        [list(['rt', 'jokermovie', 'passed', 'deadpool', '783m', 'deadpool2', '785m', 'counting', '50m', 'pg-13', 'upon', 'deadpool', '…']),
#         None, 'positive'],
#        [list(['hell', 'whole', 'point', 'movie', 'standalone', 'film', 'sequels', 'spin-offs', 'con…']),
#         None, 'negative'],
#        [list(['rt', 'done', 'movies', 'bts', 'bring', 'soul', 'movie', 'weathering', 'joker', 'spiderman', 'far', 'from…']),
#         None, 'positive'],
#        [list(['『ジョーカー』ホアキン・フェニックスがアーサーの幼少期を語る——なぜ彼は地下鉄で〇〇しなかったのか']),
#         None, 'negative'],
#        [list(['rt', '``', 'jokes', "''", 'acrylic', 'canvas', 'loved', 'joker', 'movie', 'reminds', 'society', 'wearenigeriancreatives']),
#         None, 'positive'],
#        [list(['rt', 'robert', "'m", 'glad', 'found', 'another', 'job', 'quickly', 'kinoplex', 'shut', 'due', 'manlet', 'shortages', 'popcorn', 'min…']),
#         None, 'positive'],
#        [list(['rt', 'trump', 'mentally', 'ill', 'villain', 'likes', 'watch', 'movie', 'joker', 'gop', 'russian', 'traitors', 'plan', 'impeachment', 'trial', 'strat…']),
#         None, 'negative'],
#        [list(['rt', '``', 'jokes', "''", 'acrylic', 'canvas', 'loved', 'joker', 'movie', 'reminds', 'society', 'wearenigeriancreatives']),
#         None, 'positive'],
#        [list(['rt', 'done', 'movies', 'bts', 'bring', 'soul', 'movie', 'weathering', 'joker', 'spiderman', 'far', 'from…']),
#         None, 'positive'],
#        [list(['rt', '``', 'jokes', "''", 'acrylic', 'canvas', 'loved', 'joker', 'movie', 'reminds', 'society', 'wearenigeriancreatives']),
#         None, 'positive'],
#        [list(['rt', 'would', 'like', 'see', 'sequel', 'joaquin', 'phoenix', "'s", 'joker']),
#         None, 'negative'],
#        [list(['trump', 'mentally', 'ill', 'villain', 'likes', 'watch', 'movie', 'joker', 'gop', 'russian', 'traitors', 'plan', 'impeachment', 't…']),
#         None, 'positive'],
#        [list(['rt', 'honestly', 'think', 'movie', 'deserving', 'tittle', '``', 'highest', 'grossing', 'r-rated', 'film', 'time', "''", "'s", 'i…']),
#         None, 'negative'],
#        [list(['rt', 'would', 'like', 'see', 'sequel', 'joaquin', 'phoenix', "'s", 'joker']),
#         None, 'negative'],
#        [list(['movie', 'joker', 'joker', 'society']), None, 'negative'],
#        [list(['rt', 'war', '52nd', 'day', 'collection', '🔥', 'hindi', '₹', '303.61', 'cr', 'total', '₹', '318.87', 'cr', '💵', 'worldwide', '₹', '478.50', 'cr', 'top', '6th', 'movie', 'tym', '🙏🏻', 'agr…']),
#         None, 'negative'],
#        [list(['rt', 'would', 'like', 'see', 'sequel', 'joaquin', 'phoenix', "'s", 'joker']),
#         None, 'negative'],
#        [list(['rt', '🤡', 'thinking', 'checking', 'new', 'joker', 'film', 'published', 'honest', 'opinion', 'movie', 'expect', '…']),
#         None, 'positive'],
#        [list(['joker', 'movie', 'stand', 'second', 'time', 'without', 'batman']),
#         None, 'negative'],
#        [list(['first', 'marvel', 'movie', 'chronologically', 'joker']),
#         None, 'negative'],
#        [list(['rt', 'would', 'like', 'see', 'sequel', 'joaquin', 'phoenix', "'s", 'joker']),
#         None, 'negative'],
#        [list(['rt', 'last', 'time', 'islanders', 'lost', 'regulation', 'joker', 'top', 'movie', 'box', 'office', 'gallon', 'gas', 'cost', '2.6…']),
#         None, 'negative'],
#        [list(['rt', '🤡', 'thinking', 'checking', 'new', 'joker', 'film', 'published', 'honest', 'opinion', 'movie', 'expect', '…']),
#         None, 'positive'],
#        [list(['yes', 'need', 'sequel', '1st', 'one', 'greatest', 'one', 'sides', 'every', 'one', 'talked', '’', 'j…']),
#         None, 'negative'],
#        [list(['watching', 'joker', 'movie']), None, 'positive'],
#        [list(['rt', 'would', 'like', 'see', 'sequel', 'joaquin', 'phoenix', "'s", 'joker']),
#         None, 'negative'],
#        [list(['اوفر', 'راتد', '—', 'watching', 'joker', 'movie']), None,
#         'positive'],
#        [list(['rt', '``', 'jokes', "''", 'acrylic', 'canvas', 'loved', 'joker', 'movie', 'reminds', 'society', 'wearenigeriancreatives']),
#         None, 'positive'],
#        [list(['rt', 'would', 'amusing', 'joker', 'movie', 'existed', 'world', 'next', '``', 'normal', "''", 'batman', 'movie', 'movi…']),
#         None, 'negative'],
#        [list(['rt', '``', 'jokes', "''", 'acrylic', 'canvas', 'loved', 'joker', 'movie', 'reminds', 'society', 'wearenigeriancreatives']),
#         None, 'positive'],
#        [list(['rt', 'done', 'movies', 'bts', 'bring', 'soul', 'movie', 'weathering', 'joker', 'spiderman', 'far', 'from…']),
#         None, 'positive'],
#        [list(['really', 'great', 'take', 'review', 'joker', 'movie', 'valid', 'criticism', 'respect', 'personally', 'i…']),
#         None, 'negative'],
#        [list(['rt', 'war', '52nd', 'day', 'collection', '🔥', 'hindi', '₹', '303.61', 'cr', 'total', '₹', '318.87', 'cr', '💵', 'worldwide', '₹', '478.50', 'cr', 'top', '6th', 'movie', 'tym', '🙏🏻', 'agr…']),
#         None, 'negative'],
#        [list(['lol', '’', 'interested', 'joker', 'movie', '’', 'prob', 'watch', 'soon', 'let', 'know', 'watching']),
#         None, 'positive'],
#        [list(['joker', 'celebrated', 'character', 'let', "'s", 'say', 'best', 'animated', 'short', 'movie']),
#         None, 'negative'],
#        [list(['rt', 'done', 'movies', 'bts', 'bring', 'soul', 'movie', 'weathering', 'joker', 'spiderman', 'far', 'from…']),
#         None, 'positive'],
#        [list(['rt', 'last', 'time', 'islanders', 'lost', 'regulation', 'joker', 'top', 'movie', 'box', 'office', 'gallon', 'gas', 'cost', '2.6…']),
#         None, 'negative'],
#        [list(['beat', 'sheet', 'top', 'grossing', 'rated', 'r', 'movie', 'time', 'enjoy😺😺😺']),
#         None, 'negative'],
#        [list(['rt', 'joker', 'movie', 'stupid', 'dry', '...', 'omg', 'waste', 'time']),
#         None, 'positive'],
#        [list(['rt', 'joker', 'staircase', 'dance', 'scene', 'absolutely', 'best', 'thing', "'ll", 'ever', 'see', 'movie', 'imagine', 'sta…']),
#         None, 'positive'],
#        [list(['rt', 'would', 'like', 'see', 'sequel', 'joaquin', 'phoenix', "'s", 'joker']),
#         None, 'negative'],
#        [list(['rt', 'would', 'like', 'see', 'sequel', 'joaquin', 'phoenix', "'s", 'joker']),
#         None, 'negative'],
#        [list(['rt', '＃joker', 'hey', 'guys', 'translated', 'joker', 'introductions', 'english🤡please', 'read', 'review', 'preparation', 'mo…']),
#         None, 'negative'],
#        [list(['rt', 'would', 'like', 'see', 'sequel', 'joaquin', 'phoenix', "'s", 'joker']),
#         None, 'negative'],
#        [list(['late', 'party', '’', 'ridiculous', 'good', 'movie', '“', 'joker', '”', '🤯👌🏻']),
#         None, 'negative'],
#        [list(['rt', 'would', 'like', 'see', 'sequel', 'joaquin', 'phoenix', "'s", 'joker']),
#         None, 'negative'],
#        [list(['rt', '``', 'joker', "''", 'todd', 'phillips', '2019', 'otra', 'escena', 'para', 'el', 'recuerdo', 'qué', 'fotografía', 'qué', 'actuación', 'qué', 'banda', 'sonora', 'impresionante…']),
#         None, 'negative'],
#        [list(['rt', 'towson', 'student', 'arrested', 'yesterday', 'tweeting', 'mood', 'commit', 'mass', 'homicide', 'appealing', 'th…']),
#         None, 'positive'],
#        [list(['would', 'like', 'see', 'sequel', 'joaquin', 'phoenix', "'s", 'joker']),
#         None, 'negative'],
#        [list(['selera', 'movie', 'ku', 'itu', 'gimana', 'sih', 'ya', 'kemarin', 'baru', 'nonton', 'joker', 'yaa', 'di', 'laptop', 'sih', 'yg', 'katanya', 'hype', 'ternyata', 'tidak', 'ses…']),
#         None, 'positive'],
#        [list(['rt', 'popeye', '’', 'chicken', 'like', 'new', 'joker', 'movie', 'product', 'outstanding', 'really', 'enjoy', '’', 'want', 'kids…']),
#         None, 'positive'],
#        [list(['joker', 'movie🙆🏽\u200d♀️😭']), None, 'negative'],
#        [list(['rt', 'todd', 'mcfarlane', 'says', 'joker', 'paved', 'way', 'r-rated', 'spawn', 'movie']),
#         None, 'negative'],
#        [list(['joker', 'joaquin', 'phoenix', "'s", 'first', 'choice', 'movie', 'get', 'superhero', 'genre', 'unfortunately', 'studio', 'exec…']),
#         None, 'negative'],
#        [list(['2h', '17mins', 'movie', 'jared', 'leto', 'got', '10mins', 'screen', 'time', 'joaqin', 'phoenix', 'got', 'whole', 'movie', 'heath', 'ledger', 'got', 'wh…']),
#         None, 'negative'],
#        [list(['الاوسكار', 'تلوح', 'في', 'الأفق', '💓', 'فيلم', 'عظيم', 'وأداء', 'عظيم', 'من', 'خواكين\u2066♥️\u2069', '—', 'watching', 'joker', 'movie']),
#         None, 'positive']], dtype=object)

# %%
# Check first 10 Tweets words and their attributed labels
test_labels[0]
# Out:
# array([list(['finally', 'saw', 'joker', 'technical', 'aspects', 'movie', 'stunning', 'acting', 'incredible', 'migh…']),
#        None, 'positive'], dtype=object)

# %%
test_labels[1]
# Out:
# array([list(['``', 'joker', "''", 'became', 'first', 'r-rated', 'movie', 'hit', '1', 'billion', 'box-office', 'are\u200b', 'rumors', 'sequel']),
#        None, 'negative'], dtype=object)

# %%
test_labels[2]
# Out:
# array([list(['would', 'like', 'see', 'sequel', 'joaquin', 'phoenix', "'s", 'joker']),
#        None, 'negative'], dtype=object)

# %%
test_labels[3]
# Out:
# array([list(['rt', 'done', 'movies', 'bts', 'bring', 'soul', 'movie', 'weathering', 'joker', 'spiderman', 'far', 'from…']),
#        None, 'positive'], dtype=object)

# %%
test_labels[4]
# Out:
# array([list(['ashishchanchalani', 'ashishchanchalanimemes', 'oldvideos', 'joker', 'think', 'downloaded', 'wrong', 'joker', 'movie']),
#        None, 'negative'], dtype=object)

# %%
test_labels[5]
# Out:
# array([list(['think', 'joker', 'new', 'favorite', 'character/movie', 'love', 'every', 'actor', '’', 'played', 'get', 'new', 'parts', 'him…']),
#        None, 'positive'], dtype=object)

# %%
test_labels[6]
# Out:
# array([list(['rt', 'still', 'thinking', 'sana', 'harley', 'quinn', 'wanted', 'chaeyoung', 'joker', 'coz', 'chaeyoung', 'love', 'movie…']),
#        None, 'negative'], dtype=object)

# %%
test_labels[7]
# Out:
# array([list(['joker', 'action', 'movie']), None, 'positive'], dtype=object)

# %%
test_labels[8]
# Out:
# array([list(['saw', 'ford', 'v', 'ferrari', 'last', 'weekend', 'great', 'movie', 'would', 'top', 'list', '2019', "'m", 'marvel', 'guy', 'avengers…']),
#        None, 'positive'], dtype=object)

# %%
test_labels[9]
# Out:
# array([list(['’', 'dope', 'joker', 'movie']), None, 'positive'],
#       dtype=object)

# %% [markdown]
# **Observations of Tweets and assigned label:**
# - Tweet[0]: At a glance, we see words such as 'stunning', 'incredible' that are positive. The label is therefore 'positive' as expected. CORRECT
# - Tweet[1]: This tweet seems rather neutral, but is classified as 'negative'. BIAS?
# - Tweet[2]: This tweet seems rather neutral, but is classified as 'negative'. BIAS?
# - Tweet[3]: This tweet seems rather neutral, but is classified as 'positive'. BIAS?
# - Tweet[4]: This tweet seems rather neutral, but is classified as 'negative'. BIAS?
# - Tweet[5]: This tweet seems rather positive with the word 'love', 'favorite'. The label is therefore 'positive' as expected. CORRECT
# - Tweet[6]: This tweet seems rather neutral, with a small positive touch with the word 'love'. However, the label is 'negative'. WRONG
# - Tweet[7]: This tweet seems rather neutral, but is classified as 'negative'. BIAS?
# - Tweet[8]: At a glance, we see words such as 'great', 'top' that are positive. The label is therefore 'positive' as expected. CORRECT
# - Tweet[9]: This tweet seems rather neutral, with a small positive note 'dope'. The label is therefore 'positive' as expected. CORRECT
#
# **As a conclusion, we see different cases:**
# 1. **50%** | It seems like neutral Tweets are more often classified as negative (4/5) which is a consequence of simplifying the classification options to two (positive and negative). More rarely (1/5), a neutral Tweet is classified as positive.
# 2. **40%** | Correct classification of the Tweet
# 3. **10%** | Wrong classfication of the Tweet
#
# This (subjective) performance evaluation task is telling us that the classification model is not optimal yet.
#
# **Possible improvements:**
# - Trying different combinations of pre-processing steps
# - Adding some pre-processing steps
# - Checking the impact of each pre-processing step on model performance
# - Building our own Training Dataset, to control quality of the classification in the Training Dataset, as it is crucial to a good model performance.

# %% [markdown]
# ## Conclusion
#
# Sentiment Analysis is an interesting way to think about the applicability of Natural Language Processing in making automated conclusions about text. It is being utilized in social media trend analysis and, sometimes, for marketing purposes. Making a Sentiment Analysis program in Python is not a difficult task, thanks to modern-day, ready-for-use libraries.
#
# With this project, we wanted to analyze Tweets about the late released movie "Joker" that attracted all kinds of comments, critics on the web. In summary, we have
#
# - created a Test set directly from Twitter thanks to the API
# - used an existing Training set that was classified into positive and negative tweets according to its content by hand
# - cleaned both sets by removing any signs (punctuation, hashtags...) that do not bring anything to the sentiment analysis
# - created a vocabulary of words based on the Training Set
# - matched tweets against vocabulary
# - trained the classifier
# - tested the model on the test Set
# - evaluated the performance of our model
#
# The result of the sentiment analysis is that almost half of the Tweets in the Test set are classified as negative and the other half as positive. The results show the divided critics about the movie, which is a feeling I had when scanning through articles on the web.
#
# However, the quality of our model seems compromised, and several areas of improvement have been identified above.
# I would not use the model per se, but most probably after implementing the different changes mentionned above.
#
# Another area of improvement to the model is in regards to measuring the performance of our model. The way the project was conducted didn't allow to use a solid model performance tool such as a confusion matrix. What could be done to measure better the model's performance would be to:
# - separate the Training Tweets Dataset between Train and Test sets
# - develop and train the model on the Train set
# - use Test set to test model
# - run metrics (confusion matrix) to evaluate model's performance over Test set and Train set
